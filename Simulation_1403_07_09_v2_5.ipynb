# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-talebi/proposal_master/blob/main/Simulation_1403_07_09_v2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install fitter
# Out:
# Requirement already satisfied: fitter in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from fitter) (8.1.7)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.4.2)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (0.7.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (3.9.2)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from fitter) (2.1.4)
# Requirement already satisfied: rich-click<2.0.0,>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.8.3)
# Requirement already satisfied: scipy<2.0.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (4.66.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.1)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (13.8.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->fitter) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (0.1.2)

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D
import os
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier , ExtraTreesClassifier
from fitter import Fitter, get_common_distributions, get_distributions
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense , Dropout
from tensorflow.keras.utils import to_categorical

# %%
root_path = '/content/drive/MyDrive/Malek_Master/code/Total_Data_Simulation'

# %%
total_file_link = []
for i in os.listdir(root_path) :
  total_file_link.append(root_path+f'/{i}')

# %%
pd.read_csv(total_file_link[2])
# Out:
#        r/R  mean_delta_x  std_delta_x  mean_delta_y  std_delta_y  \
# 0   0.2001        0.0434       0.0026       -0.0126       0.0013
# 1   0.2499       -0.0157       0.0019       -0.0235       0.0031
# 2   0.2998       -0.0418       0.0016       -0.0514       0.0053
# 3   0.3498       -0.0550       0.0016       -0.0961       0.0091
# 4   0.3913       -0.0646       0.0024       -0.1332       0.0133
# 5   0.4496       -0.1020       0.0026       -0.1704       0.0173
# 6   0.4997       -0.1255       0.0030       -0.2004       0.0207
# 7   0.5387       -0.1535       0.0028       -0.2193       0.0230
# 8   0.5996       -0.1964       0.0031       -0.2466       0.0273
# 9   0.6498       -0.2235       0.0031       -0.2726       0.0316
# 10  0.6998       -0.2741       0.0030       -0.2945       0.0354
# 11  0.7500       -0.3002       0.0029       -0.3091       0.0391
# 12  0.8001       -0.3363       0.0029       -0.3486       0.0430
# 13  0.8497       -0.3810       0.0031       -0.3719       0.0474
# 14  0.9102       -0.4236       0.0032       -0.3486       0.0526
# 15  0.9734       -0.3914       0.0037       -0.3834       0.0581
#
#     mean_delta_z  std_delta_z
# 0        -0.0162       0.0040
# 1        -0.0061       0.0079
# 2        -0.0781       0.0130
# 3        -0.1268       0.0216
# 4        -0.1839       0.0303
# 5        -0.3251       0.0405
# 6        -0.4803       0.0503
# 7        -0.6758       0.0569
# 8        -0.9893       0.0678
# 9        -1.3829       0.0783
# 10       -1.7870       0.0876
# 11       -2.2590       0.0965
# 12       -2.7745       0.1069
# 13       -3.3516       0.1185
# 14       -4.1247       0.1339
# 15       -4.8769       0.1475

# %%
total_alpha_content = [ i / 1000 for i in range( 60 , 61 ) ]
total_flat_content  = [ i for i in range(1 , 10  ) ]
total_location      = list(range( 8 , 16))

# %%
points = []
start_x = 65
start_y = [0 , -5 , -10.0 ]
for i in range(15) :
  start_x +=  15

  for j in range(3) :
    points.append([start_x , start_y[j] , 0 ] )

points.append([330 , -2.5 , 0 ])
points.append([330 , -7.5 , 0 ])
points.append([330 , -12.5 , 0 ])
total_points = np.array(points)
plt.scatter(total_points[ : ,  0 ] , total_points[ : , 1 ] , label = "target" )
plt.legend()
plt.title("Blade Shape - Picture 1.7 page 7 document volume 2 ")
plt.xlabel(" X (in) ")
plt.ylabel(" Y (in) ")
plt.grid()
plt.show()

# %%
total_simulation = {
    'bias_correlation' : [] ,
    'betha_0_correlation' : [] ,
    'betha_1_correlation' : [] ,
    'betha_2_correlation' : [] ,
    'betha_3_correlation' : [] ,
    'betha_4_correlation' : [] ,
    'betha_5_correlation' : [] ,
    'alpha' : [] ,
    'flap'  : [] ,
    'accuracy_nav' : [] ,

    'accuracy_random_forest' : [] ,
    'n_estimators_RF' : [] ,
    'max_features_RF' : [] ,
    'max_depth_RF'    : [] ,
    'criterion_RF'    : [] ,

    'accuracy_extra_classifier' : [] ,
    'accuracy_svc_' : [] ,
    'C_svc'         : [] ,
    'kernel_svc'    : [] ,
    'gamma_svc'     : [] ,


}



MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH = {
    'mean_bias'    : [] ,
    'std_bias'     : [] ,
    'mean_betha_0' : [] ,
    'std_betha_0'  : [] ,
    'mean_betha_1' : [] ,
    'std_betha_1'  : [] ,
    'mean_betha_2' : [] ,
    'std_betha_2'  : [] ,
    'mean_betha_3' : [] ,
    'std_betha_3'  : [] ,
    'mean_betha_4' : [] ,
    'std_betha_4'  : [] ,
    'mean_betha_5' : [] ,
    'std_betha_5'  : [] ,
}



MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T = {
    'mean_bias'    : [] ,
    'std_bias'     : [] ,
    'mean_betha_0' : [] ,
    'std_betha_0'  : [] ,
    'mean_betha_1' : [] ,
    'std_betha_1'  : [] ,
    'mean_betha_2' : [] ,
    'std_betha_2'  : [] ,
    'mean_betha_3' : [] ,
    'std_betha_3'  : [] ,
    'mean_betha_4' : [] ,
    'std_betha_4'  : [] ,
    'mean_betha_5' : [] ,
    'std_betha_5'  : [] ,
}


MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT = {
    'mean_bias'    : [] ,
    'std_bias'     : [] ,
    'mean_betha_0' : [] ,
    'std_betha_0'  : [] ,
    'mean_betha_1' : [] ,
    'std_betha_1'  : [] ,
    'mean_betha_2' : [] ,
    'std_betha_2'  : [] ,
    'mean_betha_3' : [] ,
    'std_betha_3'  : [] ,
    'mean_betha_4' : [] ,
    'std_betha_4'  : [] ,
    'mean_betha_5' : [] ,
    'std_betha_5'  : [] ,
}



MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T = {
    'mean_bias'    : [] ,
    'std_bias'     : [] ,
    'mean_betha_0' : [] ,
    'std_betha_0'  : [] ,
    'mean_betha_1' : [] ,
    'std_betha_1'  : [] ,
    'mean_betha_2' : [] ,
    'std_betha_2'  : [] ,
    'mean_betha_3' : [] ,
    'std_betha_3'  : [] ,
    'mean_betha_4' : [] ,
    'std_betha_4'  : [] ,
    'mean_betha_5' : [] ,
    'std_betha_5'  : [] ,
}

# %%
for iter_alpha in total_alpha_content :
  for iter_flat in total_flat_content :
    print(f"iter_alpha : {iter_alpha} | iter_flat : {iter_flat} ")
    params_health   = []
    params_fault    = []
    params_fault_t  = []
    params_health_t = []
    for iter_link in total_file_link :
      df_table_change     = pd.read_csv(iter_link)
      for locate in total_location:
        related_x = -1
        related_y = -1
        related_z = -1
        for iteration in range(40):
          alpha = 0
          term  = 0
          Flat_Add = 0
          noise_activate = ( (np.random.randn() + 1 ) / 100 )
          #print( f'Alpha : {iter_alpha} ' ,  f'Table Change : {iter_link}' , ' -- ' , f'Locate : {locate} ' , ' -- ' , f"Iter : {iteration}" , ' -- ' , '')
          select_location_combin_flap_term = 0
          select_locatiom_flap = 0

          total_health_iter  = []
          total_health_iter_t = []
          total_fault_iter   = []
          total_fault_t_iter = []
          new_data_simulated_ = []
          new_data_simulated_fault = []
          new_data_simulated_fault_t = []
          new_data_simulated_health_t = []



          for i in range(df_table_change.shape[0]):
            x_mean = df_table_change.iloc[i, 1]
            x_std  = df_table_change.iloc[i, 2]
            y_mean = df_table_change.iloc[i, 3]
            y_std  = df_table_change.iloc[i, 4]
            z_mean = df_table_change.iloc[i, 5]
            z_std  = df_table_change.iloc[i, 6]

            if i > locate :
              alpha = iter_alpha
              term  = -1 * ( alpha * abs( i - locate ) + noise_activate )
              Flat_Add  = iter_flat / 10

            for element in total_points[i * 3: (i + 1) * 3, :]:
              x_sample = element[0]
              y_sample = element[1]
              z_sample = element[2]
              rng = np.random.default_rng()
              x_added  = rng.normal(x_mean, x_std, size=1)
              x_added  = x_added.tolist()[0]
              x_sample += related_x * x_added

              y_added  = rng.normal(y_mean, y_std, size=1)
              y_added  = y_added.tolist()[0]
              y_sample += related_y * y_added

              z_added  = rng.normal(z_mean, z_std, size=1)
              z_base   = z_sample

              z_added_term  = z_added.tolist()[0] + term
              z_added       = z_added.tolist()[0]
              z_sample_new_term = z_base + related_z * z_added_term
              z_sample_new      = z_base + related_z * z_added
              z_flat  = z_sample_new_term
              z_flap_health = z_sample_new


              if select_location_combin_flap_term  == 0 :
                if np.random.randint(0 ,2 ) :
                  z_flat = z_sample_new_term + Flat_Add


              if select_locatiom_flap == 0 :
                if np.random.randint(0 ,2 ) :
                  z_flap_health = z_sample_new + Flat_Add







              new_data_simulated_.append([ x_sample, y_sample, z_sample_new  ])
              new_data_simulated_fault.append([ x_sample, y_sample, z_sample_new_term  ])
              new_data_simulated_fault_t.append([ x_sample, y_sample, z_flat  ])
              new_data_simulated_health_t.append([x_sample , y_sample , z_flap_health ])

              total_health_iter.append([ x_sample, y_sample, z_sample_new  ])
              total_fault_iter.append([ x_sample, y_sample, z_sample_new_term  ])
              total_fault_t_iter.append([ x_sample, y_sample, z_flat  ])
              total_health_iter_t.append([x_sample , y_sample , z_flap_health ])



          # fig = plt.figure(figsize=(20 , 10 ))

          # ax0 = fig.add_subplot(1 , 6 , 1 , projection='3d' )
          # ax1 = fig.add_subplot(1 , 6 , 2 , projection='3d' )
          # ax2 = fig.add_subplot(1 , 6 , 3 , projection='3d' )
          # ax3 = fig.add_subplot(1 , 6 , 4 , projection='3d' )
          # ax4 = fig.add_subplot(1 , 6 , 5 , projection='3d' )
          # ax5 = fig.add_subplot(1 , 6 , 6 , projection='3d' )

          # ax6 = fig.add_subplot(3 , 6 , 1 )
          # ax7 = fig.add_subplot(3 , 6 , 2 )
          # ax8 = fig.add_subplot(3 , 6 , 3 )

          # # ax3 = fig.add_subplot(1 , 6 , 4 )
          # # ax4 = fig.add_subplot(1 , 6 , 5 )
          # # ax5 = fig.add_subplot(1 , 6 , 6 )






          # total_health_iter = np.array(total_health_iter)
          # total_health_iter = np.array(total_health_iter)
          # total_fault_iter = np.array(total_fault_iter)
          # total_fault_t_iter = np.array(total_fault_t_iter)
          # total_health_iter_t = np.array(total_health_iter_t)
          # print(f"iter_alpha : {iter_alpha} , flap: {iter_flat} , locate : {locate} ,  iteration : {iteration} ")

          # ax0.scatter3D(total_health_iter[: , 0 ] , total_health_iter[: , 1 ] , total_health_iter[: , 2 ]  , label='health' , c = 'r'   )
          # ax0.scatter3D(total_fault_iter[: , 0 ] , total_fault_iter[: , 1 ] , total_fault_iter[: , 2 ]  , label='fault_alpha' ,  c = 'b' )
          # ax1.scatter3D(total_fault_iter[: , 0 ] , total_fault_iter[: , 1 ] , total_fault_iter[: , 2 ]  ,       label='fault_alpha' , c ='blue', s = 30 , alpha = 0.5    )
          # ax1.scatter3D(total_fault_t_iter[: , 0 ] , total_fault_t_iter[: , 1 ] , total_fault_t_iter[: , 2 ]  , label='fault_alpha + void ' , c='red' , s = 30 )
          # ax2.scatter3D(total_fault_t_iter[: , 0 ] , total_fault_t_iter[: , 1 ] , total_fault_t_iter[: , 2 ]  , label='fault_alpha + void ' , c='red'  , s = 30  )

          # ax3.scatter3D(total_health_iter[: , 0 ] , total_health_iter[: , 1 ]  , total_health_iter[: , 2 ]  ,       label='fault_void' , c ='blue'  )
          # ax3.scatter3D(total_fault_iter[: , 0 ] , total_fault_iter[: , 1]  , total_fault_iter[: , 2 ]  ,       label='fault_alpha' , c ='red' )
          # ax3.set_xlabel("axis x ")
          # ax3.set_ylabel("axis y ")

          # ax4.scatter3D(total_health_iter[: , 0 ] , total_health_iter[: , 1 ]  , total_health_iter[: , 2 ]  ,       label='health' , c ='blue',  )
          # ax4.scatter3D(total_fault_t_iter[: , 0 ] , total_health_iter[: , 1 ]  , total_fault_t_iter[: , 2 ]  , label='fault_alpha+ void ' , c='red' ,  )
          # ax4.set_xlabel("axis x")
          # ax4.set_ylabel("axis y")

          # ax5.scatter3D(total_health_iter[: , 0 ]  , total_health_iter[: , 1 ] , total_fault_iter[: , 2 ]  ,       label='health' , c ='blue' ,  )
          # ax5.scatter3D(total_health_iter_t[: , 0 ] , total_health_iter_t[: , 1] , total_fault_t_iter[: , 2 ]  , label='fault_void' , c='red' ,  )
          # ax5.set_xlabel("axis x ")
          # ax5.set_ylabel("axis y ")

          # ax6.scatter(total_health_iter[: , 0 ]  , total_health_iter[: , 2 ]  , label='health' , c='b' , s = 40 , alpha = 0.7 )
          # ax6.scatter(total_health_iter_t[: , 0 ]  , total_fault_iter[: , 2 ]  , label='fault_void' , c='r' , s = 30 , alpha = 0.6  )
          # ax6.set_xlabel("axis  x ")
          # ax6.set_ylabel("axis  y ")
          # ax6.set_title(f"alpha : {iter_alpha} , void : {iter_flat/10} ")

          # ax7.scatter(total_health_iter[: , 0 ]  , total_health_iter[: , 2 ]  , label='health' , c='b' , s = 40 , alpha = 0.2 )
          # ax7.scatter(total_fault_t_iter[: , 0 ]  , total_fault_t_iter[: , 2 ]  , label='fault_alpha + void ' , c='r' , s = 30 , alpha = 0.5  )
          # ax7.set_xlabel("axis  x ")
          # ax7.set_ylabel("axis  y ")

          # ax8.scatter(total_fault_iter[: , 0 ]  , total_fault_iter[: , 2 ]  , label='fault_alpha' , c='b' , )
          # ax8.scatter(total_fault_t_iter[: , 0 ]  , total_fault_t_iter[: , 2 ]  , label='F_alpha + void' , c='r')
          # ax8.set_xlabel("axis  x ")
          # ax8.set_ylabel("axis  y ")


          # ax0.legend()
          # ax0.grid()
          # ax0
          # ax1.legend()
          # ax1.grid()
          # ax2.legend()
          # ax2.grid()
          # ax3.legend()
          # ax3.grid()

          # ax4.legend()
          # ax4.grid()
          # ax5.legend()
          # ax5.grid()


          # ax6.legend()
          # ax6.grid()

          # ax7.legend()
          # ax7.grid()
          # ax8.legend()
          # ax8.grid()

          # plt.show()




          new_data_simulated_         = np.array(new_data_simulated_)
          new_data_simulated_fault    = np.array(new_data_simulated_fault)
          new_data_simulated_fault_t  = np.array(new_data_simulated_fault_t)
          new_data_simulated_health_t = np.array(new_data_simulated_health_t)


          #fig = plt.figure(figsize=(30, 10))
          df_health = pd.DataFrame()
          df_health['X_'] = new_data_simulated_[:, 0]
          df_health['Y_'] = new_data_simulated_[:, 1]
          df_health['Z_'] = new_data_simulated_[:, 2]

          poly = PolynomialFeatures(degree=2)
          x_poly = poly.fit_transform(df_health[['X_', 'Y_']])
          scaler = StandardScaler()
          df_stander = pd.DataFrame(scaler.fit_transform(x_poly), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander['Z_'] = df_health['Z_']
          x_train, x_test, z_train, z_test = train_test_split(df_stander[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']],
                                                                          df_stander["Z_"])
          model = LinearRegression()
          model.fit(x_train, z_train)
          z_predict = model.predict(x_test)
          intercept_0 = model.intercept_
          coef1 = model.coef_[0]
          coef2 = model.coef_[1]
          coef3 = model.coef_[2]
          coef4 = model.coef_[3]
          coef5 = model.coef_[4]
          coef6 = model.coef_[5]

          total_new_generate = []
          total_error_health = 0
          for i in range(len(df_health['X_'])):
            new_value = intercept_0 + coef1 * df_stander.iloc[i, 0] + coef2 * df_stander.iloc[i, 1] + coef3 * df_stander.iloc[i, 2] + coef4 * df_stander.iloc[i, 3] + coef5 * df_stander.iloc[i, 4]
            + coef6 * df_stander.iloc[i, 5]
            total_new_generate.append(new_value)
            error = df_stander.iloc[i, -1] - new_value
            total_error_health += error

          print("Error in Simulation Health for Each Blade : " , total_error_health )

          #class health == 0
          params_health.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict, z_test),locate , 0 , iter_alpha ,  iter_flat  ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]

          # ---- setup for class health t ----

          df_health_t = pd.DataFrame()
          df_health_t['X_'] = new_data_simulated_health_t[:, 0]
          df_health_t['Y_'] = new_data_simulated_health_t[:, 1]
          df_health_t['Z_'] = new_data_simulated_health_t[:, 2]

          poly_health_t = PolynomialFeatures(degree=2)
          x_poly_health_t = poly_health_t.fit_transform(df_health_t[['X_', 'Y_']])
          scaler_health_t = StandardScaler()
          df_stander_health_t = pd.DataFrame(scaler_health_t.fit_transform(x_poly_health_t), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander_health_t['Z_'] = df_health_t['Z_']
          x_train, x_test, z_train, z_test = train_test_split(df_stander_health_t[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']],
                                                                          df_stander["Z_"])
          model_health_t = LinearRegression()
          model_health_t.fit(x_train, z_train)
          z_predict_health_t = model_health_t.predict(x_test)
          intercept_0 = model_health_t.intercept_
          coef1 = model_health_t.coef_[0]
          coef2 = model_health_t.coef_[1]
          coef3 = model_health_t.coef_[2]
          coef4 = model_health_t.coef_[3]
          coef5 = model_health_t.coef_[4]
          coef6 = model_health_t.coef_[5]

          total_new_generate_health_t = []
          total_error_health_t = 0
          for i in range(len(df_health['X_'])):
            new_value = intercept_0 + coef1 * df_stander_health_t.iloc[i, 0] + coef2 * df_stander_health_t.iloc[i, 1] + coef3 * df_stander_health_t.iloc[i, 2] + coef4 * df_stander_health_t.iloc[i, 3] + coef5 * df_stander_health_t.iloc[i, 4]
            + coef6 * df_stander_health_t.iloc[i, 5]
            total_new_generate_health_t.append(new_value)
            error = df_stander_health_t.iloc[i, -1] - new_value
            total_error_health_t += error

          print("Error in Simulation Health T  for Each Blade : " , total_error_health_t )

          #class health == 0
          params_health_t.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict_health_t, z_test),locate , 1 , iter_alpha ,  iter_flat  ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]





          # ---- setup for class Fault ----
          df_fault = pd.DataFrame()
          df_fault['X_'] = new_data_simulated_fault[:, 0]
          df_fault['Y_'] = new_data_simulated_fault[:, 1]
          df_fault['Z_'] = new_data_simulated_fault[:, 2]




          poly_fault = PolynomialFeatures(degree=2)
          x_poly_fault = poly_fault.fit_transform(df_fault[['X_', 'Y_']])
          scaler_fault = StandardScaler()
          df_stander_fault = pd.DataFrame(scaler_fault.fit_transform(x_poly_fault), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander_fault['Z_'] = df_fault['Z_']
          x_train_fault , x_test_fault , z_train_fault , z_test_fault = train_test_split(df_stander_fault[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']], df_stander_fault["Z_"])
          model_fault = LinearRegression()
          model_fault.fit(x_train_fault, z_train_fault)
          z_predict_fault = model_fault.predict(x_test_fault)
          intercept_0 = model_fault.intercept_
          coef1 = model_fault.coef_[0]
          coef2 = model_fault.coef_[1]
          coef3 = model_fault.coef_[2]
          coef4 = model_fault.coef_[3]
          coef5 = model_fault.coef_[4]
          coef6 = model_fault.coef_[5]
          total_new_generate_fault = []
          total_error_fault = 0
          for i in range(len(df_fault['X_'])):
            new_value = intercept_0 + coef1 * df_stander_fault.iloc[i, 0] + coef2 * df_stander_fault.iloc[i, 1] + coef3 *  df_stander_fault.iloc[i, 2] + coef4 * df_stander_fault.iloc[i, 3] + coef5 * df_stander_fault.iloc[i, 4]  + coef6 * df_stander_fault.iloc[i, 5]
            total_new_generate_fault.append(new_value)
            error_Fault = df_stander_fault.iloc[i, -1] - new_value
            total_error_fault += error_Fault

          print("Error in Simulation Fault for Each Blade : " , total_error_fault  , " --- MSE Fault S ---- " ,  mean_squared_error(z_predict_fault, z_test_fault))


          params_fault.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict_fault, z_test_fault),locate ,  2 , iter_alpha ,  iter_flat ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]

          # ---- setup for class Fault T ----

          df_fault_t = pd.DataFrame()
          df_fault_t['X_'] = new_data_simulated_fault_t[:, 0]
          df_fault_t['Y_'] = new_data_simulated_fault_t[:, 1]
          df_fault_t['Z_'] = new_data_simulated_fault_t[:, 2]




          poly_fault_t = PolynomialFeatures(degree=2)
          x_poly_fault_t = poly_fault_t.fit_transform(df_fault_t[['X_', 'Y_']])
          scaler_fault_t = StandardScaler()
          df_stander_fault_t = pd.DataFrame(scaler_fault_t.fit_transform(x_poly_fault_t), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander_fault_t['Z_'] = df_fault_t['Z_']
          x_train_fault_t , x_test_fault_t , z_train_fault_t , z_test_fault_t = train_test_split(df_stander_fault_t[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']], df_stander_fault["Z_"])
          model_fault_t = LinearRegression()
          model_fault_t.fit(x_train_fault_t, z_train_fault_t)
          z_predict_fault = model_fault_t.predict(x_test_fault_t)
          intercept_0 = model_fault_t.intercept_
          coef1 = model_fault_t.coef_[0]
          coef2 = model_fault_t.coef_[1]
          coef3 = model_fault_t.coef_[2]
          coef4 = model_fault_t.coef_[3]
          coef5 = model_fault_t.coef_[4]
          coef6 = model_fault_t.coef_[5]
          total_new_generate_fault_t = []
          total_error_fault_t = 0
          for i in range(len(df_fault['X_'])):
            new_value = intercept_0 + coef1 * df_stander_fault_t.iloc[i, 0] + coef2 * df_stander_fault_t.iloc[i, 1] + coef3 *  df_stander_fault_t.iloc[i, 2] + coef4 * df_stander_fault_t.iloc[i, 3] + coef5 * df_stander_fault_t.iloc[i, 4]  + coef6 * df_stander_fault_t.iloc[i, 5]
            total_new_generate_fault_t.append(new_value)
            error_Fault = df_stander_fault_t.iloc[i, -1] - new_value
            total_error_fault_t += error_Fault

          print("Error in Simulation Fault T  for Each Blade : " , total_error_fault , " --- Mean Squared Error Fault T : " ,  mean_squared_error(z_predict_fault, z_test_fault)   )



          params_fault_t.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict_fault, z_test_fault),locate ,  3 , iter_alpha ,  iter_flat ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]

          print(" ----- for each Blade Simulated ----- " )



#----
    params_health = np.array(params_health)
    df_params = pd.DataFrame({'bias':params_health[: , 0 ] , 'betha_0':params_health[ : , 1 ] , 'betha_1':params_health[ : , 2 ] , 'betha_2':params_health[ : , 3 ] ,  'betha_3':params_health[ : , 4 ] , 'betha_4':params_health[ : , 5 ] , 'betha_5':params_health[ : , 6 ] , 'error' : params_health[ : , 7 ]  ,
                          'locate' : params_health[: , 8 ].astype(int)   , 'class' :params_health[: , 9 ] ,
                              'alpha' :params_health[: , 10 ] , 'flap' : params_health[: , 11 ] } )





    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_bias'].append(df_params['bias'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_bias'].append(df_params['bias'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_0'].append(df_params['betha_0'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_0'].append(df_params['betha_0'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_1'].append(df_params['betha_1'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_1'].append(df_params['betha_1'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_2'].append(df_params['betha_2'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_2'].append(df_params['betha_2'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_3'].append(df_params['betha_3'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_3'].append(df_params['betha_3'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_4'].append(df_params['betha_4'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_4'].append(df_params['betha_4'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['mean_betha_5'].append(df_params['betha_5'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH['std_betha_5'].append(df_params['betha_5'].std())

    # -------------------------------------------------------------------------------------------

    params_health_t = np.array(params_health_t)
    df_params_health_t = pd.DataFrame({'bias':params_health_t[: , 0 ] , 'betha_0':params_health_t[ : , 1 ] , 'betha_1':params_health_t[ : , 2 ] , 'betha_2':params_health[ : , 3 ] ,  'betha_3':params_health[ : , 4 ] , 'betha_4':params_health[ : , 5 ] , 'betha_5':params_health[ : , 6 ] , 'error' : params_health[ : , 7 ]  ,
                          'locate' : params_health_t[: , 8 ].astype(int)   , 'class' :params_health_t[: , 9 ] ,
                              'alpha' :params_health_t[: , 10 ] , 'flap' : params_health_t[: , 11 ] } )





    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_bias'].append(df_params_health_t['bias'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_bias'].append(df_params_health_t['bias'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_0'].append(df_params_health_t['betha_0'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_0'].append(df_params_health_t['betha_0'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_1'].append(df_params_health_t['betha_1'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_1'].append(df_params_health_t['betha_1'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_2'].append(df_params_health_t['betha_2'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_2'].append(df_params_health_t['betha_2'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_3'].append(df_params_health_t['betha_3'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_3'].append(df_params_health_t['betha_3'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_4'].append(df_params_health_t['betha_4'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_4'].append(df_params_health_t['betha_4'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['mean_betha_5'].append(df_params_health_t['betha_5'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_HEALTH_T['std_betha_5'].append(df_params_health_t['betha_5'].std())





    # --------------------------------------------------------------------------------------------
    params_fault = np.array(params_fault)
    df_params_fault = pd.DataFrame({'bias':params_fault[: , 0 ] , 'betha_0':params_fault[ : , 1 ] , 'betha_1':params_fault[ : , 2 ] , 'betha_2':params_fault[ : , 3 ] ,  'betha_3':params_fault[ : , 4 ] , 'betha_4':params_fault[ : , 5 ] , 'betha_5':params_fault[ : , 6 ] , 'error' : params_fault[ : , 7 ]  ,
                            'locate' : params_fault[: , 8 ].astype(int) ,
                                    'class' :params_fault[: , 9 ]  ,
                                    'alpha' :params_fault[: , 10 ] , 'flap' : params_fault[: , 11 ] }   )


    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_bias'].append(df_params_fault['bias'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_bias'].append(df_params_fault['bias'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_0'].append(df_params_fault['betha_0'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_0'].append(df_params_fault['betha_0'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_1'].append(df_params_fault['betha_1'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_1'].append(df_params_fault['betha_1'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_2'].append(df_params_fault['betha_2'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_2'].append(df_params_fault['betha_2'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_3'].append(df_params_fault['betha_3'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_3'].append(df_params_fault['betha_3'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_4'].append(df_params_fault['betha_4'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_4'].append(df_params_fault['betha_4'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['mean_betha_5'].append(df_params_fault['betha_5'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT['std_betha_5'].append(df_params_fault['betha_5'].std())




    params_fault_t = np.array(params_fault_t)
    df_params_fault_t = pd.DataFrame({'bias':params_fault_t[: , 0 ] , 'betha_0':params_fault_t[ : , 1 ] , 'betha_1':params_fault_t[ : , 2 ] , 'betha_2':params_fault_t[ : , 3 ] ,  'betha_3':params_fault_t[ : , 4 ] , 'betha_4':params_fault_t[ : , 5 ] , 'betha_5':params_fault_t[ : , 6 ] , 'error' : params_fault_t[ : , 7 ]  ,
                            'locate' : params_fault_t[: , 8 ].astype(int) ,
                                    'class' :params_fault_t[: , 9 ]  ,
                                    'alpha' :params_fault_t[: , 10 ] , 'flap' : params_fault_t[: , 11 ] }  )


    # check_columns = ['bias' , 'betha_0' , 'betha_1' , 'betha_2' , 'betha_3' , 'betha_4' , 'betha_5' ]
    # for element in check_columns :
    #   fig = plt.figure(figsize = (10 , 10 ))
    #   ax0 = fig.add_subplot(111 )
    #   sns.kdeplot( df_params[element]  , label=f'mean_health - {element} coef'  , shade=True )
    #   sns.kdeplot(df_params_fault[element] , label=f'mean_fault_alpha - {element} coef '  , shade=True  )
    #   sns.kdeplot(df_params_fault_t[element] , label=f'mean_fault-alpha + void- {element} coef ' ,  shade=True  )
    #   sns.kdeplot(df_params_health_t[element] , label=f'mean_fault-void- {element} coef ' ,  shade=True  )
    #   plt.legend()
    #   plt.grid()
    #   plt.show()



    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_bias'].append(df_params_fault_t['bias'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_bias'].append(df_params_fault_t['bias'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_0'].append(df_params_fault_t['betha_0'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_0'].append(df_params_fault_t['betha_0'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_1'].append(df_params_fault_t['betha_1'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_1'].append(df_params_fault_t['betha_1'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_2'].append(df_params_fault_t['betha_2'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_2'].append(df_params_fault_t['betha_2'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_3'].append(df_params_fault_t['betha_3'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_3'].append(df_params_fault_t['betha_3'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_4'].append(df_params_fault_t['betha_4'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_4'].append(df_params_fault_t['betha_4'].std())

    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['mean_betha_5'].append(df_params_fault_t['betha_5'].mean())
    MEAN_STD_FOR_EACH_ITER_ALPHA_FLAP_FAULT_T['std_betha_5'].append(df_params_fault_t['betha_5'].std())



    concat_2_df_health_fault = pd.concat([df_params , df_params_health_t , df_params_fault , df_params_fault_t ] , axis = 0 )
    df_corr = concat_2_df_health_fault.corr()







  # --- learning
    #plt.figure(figsize= (10 , 10 ) )
    #ax = sns.heatmap(df_corr , annot=True )
    #print(df_corr)
    #plt.show()
    total_simulation['alpha'].append(iter_alpha)
    total_simulation['flap'].append(iter_flat)
    total_simulation['bias_correlation'].append(df_corr['class']['bias'])
    total_simulation['betha_0_correlation'].append(df_corr['class']['betha_0'])
    total_simulation['betha_1_correlation'].append(df_corr['class']['betha_1'])
    total_simulation['betha_2_correlation'].append(df_corr['class']['betha_2'])
    total_simulation['betha_3_correlation'].append(df_corr['class']['betha_3'])
    total_simulation['betha_4_correlation'].append(df_corr['class']['betha_4'])
    total_simulation['betha_5_correlation'].append(df_corr['class']['betha_5'])



    #df2_health  =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 0 ]
    #df2_fault   =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 1 ]
    #df2_fault_t =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 2 ]


    stander_u = StandardScaler()
    stand_df_with_out = concat_2_df_health_fault.drop(['class' , 'alpha' , 'flap'] , axis = 1 )
    stand_df_with_out = pd.DataFrame(stander_u.fit_transform(stand_df_with_out )  , columns = stand_df_with_out.columns )
    x_u_train , x_u_test , y_u_train , y_u_test = train_test_split(stand_df_with_out , concat_2_df_health_fault['class'] , random_state=42 , test_size=0.2  )
    obj_gaunb = GaussianNB()
    obj_gaunb.fit(x_u_train , y_u_train )
    pre_nb = obj_gaunb.predict(x_u_test)
    accuray_nav = accuracy_score(pre_nb ,y_u_test )
    print(f"accuracy Nave Bays : {accuray_nav}")
    total_simulation['accuracy_nav'].append(accuray_nav)


    # ---------------------------------------------------------
    rfc=RandomForestClassifier(random_state=42)
    param_grid = {
        'n_estimators': [200, 500],
        'max_features': ['auto', 'sqrt', 'log2'],
        'max_depth' : [4,5,6,7,8],
        'criterion' :['gini', 'entropy']
    }

    CV_rfc = GridSearchCV(estimator=rfc, param_grid = param_grid,
                          cv = 3, n_jobs = -1, verbose = 2)
    CV_rfc.fit(x_u_train, y_u_train)
    best_params_for_random_forest = CV_rfc.best_params_
    pre_random = CV_rfc.predict(x_u_test)
    accuracy_random_forest = accuracy_score(pre_random ,y_u_test )
    print(f"accuracy accuracy_random_forest  : {accuracy_random_forest}")
    total_simulation['accuracy_random_forest'].append(accuracy_random_forest)
    total_simulation['n_estimators_RF'].append(best_params_for_random_forest['n_estimators'])
    total_simulation['max_features_RF'].append(best_params_for_random_forest['max_features'])
    total_simulation['max_depth_RF'].append(best_params_for_random_forest['max_depth'])
    total_simulation['criterion_RF'].append(best_params_for_random_forest['criterion'])


    # ---------------------------------------------------------
    extra_classifier = ExtraTreesClassifier()
    extra_classifier.fit(x_u_train , y_u_train )
    predict_extra = extra_classifier.predict(x_u_test)
    total_simulation['accuracy_extra_classifier'].append(accuracy_score(predict_extra ,y_u_test ) )

    # --------------------------------------------------------
    param_grid = {'C':[1,10,100,1000],'gamma':[1,0.1,0.001,0.0001], 'kernel':['linear','rbf']}
    grid = GridSearchCV(SVC(),param_grid,refit = True, verbose=2)
    grid.fit(x_u_train, y_u_train)
    best_params_for_svc = grid.best_params_
    model_svc = SVC()
    svc_predict = grid.predict(x_u_test)
    accuracy_svc = accuracy_score(svc_predict ,y_u_test )
    total_simulation['accuracy_svc_'].append(accuracy_svc)
    total_simulation['C_svc'].append(best_params_for_svc['C'])
    total_simulation['kernel_svc'].append(best_params_for_svc['kernel'])
    total_simulation['gamma_svc'].append(best_params_for_svc['gamma'])


    # ----------------------------------------------------------







    new_y_u_train_cat = to_categorical(y_u_train , 4 )
    new_y_u_test_cat  = to_categorical(y_u_test , 4 )

    model_learning = Sequential([
        Dense(32 , activation='relu' , input_shape = x_u_train.shape[1 : ] ) ,
        Dropout(0.2) ,
        Dense(10 , activation= 'relu' ) ,
        Dense(4 , activation='softmax' ) ,
    ])

    model_learning.compile('adam' , loss = 'categorical_crossentropy' , metrics = ['acc' ] )
    model_learning_info = model_learning.fit(x_u_train , new_y_u_train_cat , epochs = 50 , validation_data = [x_u_test , new_y_u_test_cat ] )
    plt.plot(range(50) , model_learning_info.history['acc'] , label='acc' )
    plt.plot(range(50) , model_learning_info.history['val_acc'] , label='val_acc' )
    plt.show()

    print(model_learning.evaluate(x_u_test , new_y_u_test_cat) )

    print(" ----------------- //////// End This Iter alpha and Flap //////// ------------------------- ")



    if iter_alpha > 0.063 :
      break
# Out:
# iter_alpha : 0.06 | iter_flat : 1
# Error in Simulation Health for Each Blade :  -0.13348350339703252
# Error in Simulation Health T  for Each Blade :  -0.03612381422593791
# Error in Simulation Fault for Each Blade :  1.0139188814608895  --- MSE Fault S ----  0.11240871752707059
# Error in Simulation Fault T  for Each Blade :  1.0139188814608895  --- Mean Squared Error Fault T :  7.315790568354547
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.7723803178171254
# Error in Simulation Health T  for Each Blade :  0.9882302279047201
# Error in Simulation Fault for Each Blade :  0.37714062521935854  --- MSE Fault S ----  0.08592192521534088
# Error in Simulation Fault T  for Each Blade :  0.37714062521935854  --- Mean Squared Error Fault T :  4.558043296295371
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.455583789869718
# Error in Simulation Health T  for Each Blade :  -0.5958972082170761
# Error in Simulation Fault for Each Blade :  -1.1337587491003618  --- MSE Fault S ----  0.1346290822030508
# Error in Simulation Fault T  for Each Blade :  -1.1337587491003618  --- Mean Squared Error Fault T :  7.667059254485687
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.630690541749291
# Error in Simulation Health T  for Each Blade :  0.5115063405133731
# Error in Simulation Fault for Each Blade :  -1.238032297632814  --- MSE Fault S ----  0.3088534753969951
# Error in Simulation Fault T  for Each Blade :  -1.238032297632814  --- Mean Squared Error Fault T :  11.654716637916797
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.7356587957363692
# Error in Simulation Health T  for Each Blade :  -0.39814727503277214
# Error in Simulation Fault for Each Blade :  -0.6585753274065989  --- MSE Fault S ----  0.17062386323416276
# Error in Simulation Fault T  for Each Blade :  -0.6585753274065989  --- Mean Squared Error Fault T :  11.686264796162606
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.2239596156890977
# Error in Simulation Health T  for Each Blade :  0.8482846962190314
# Error in Simulation Fault for Each Blade :  -1.4176929033031502  --- MSE Fault S ----  0.11318563526123886
# Error in Simulation Fault T  for Each Blade :  -1.4176929033031502  --- Mean Squared Error Fault T :  8.515846050720983
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.8402513149052453
# Error in Simulation Health T  for Each Blade :  -0.5371746536392483
# Error in Simulation Fault for Each Blade :  1.422112924753324  --- MSE Fault S ----  0.041639945455287465
# Error in Simulation Fault T  for Each Blade :  1.422112924753324  --- Mean Squared Error Fault T :  10.926024064151804
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.49986255816945646
# Error in Simulation Health T  for Each Blade :  2.0718251927969695
# Error in Simulation Fault for Each Blade :  0.9877688754127654  --- MSE Fault S ----  0.05878489071834577
# Error in Simulation Fault T  for Each Blade :  0.9877688754127654  --- Mean Squared Error Fault T :  10.644242899322762
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.9610711696158871
# Error in Simulation Health T  for Each Blade :  0.008318165757022378
# Error in Simulation Fault for Each Blade :  1.0222665331757121  --- MSE Fault S ----  0.10708917695562808
# Error in Simulation Fault T  for Each Blade :  1.0222665331757121  --- Mean Squared Error Fault T :  14.953575799160573
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.02346505606344018
# Error in Simulation Health T  for Each Blade :  -0.587708547953625
# Error in Simulation Fault for Each Blade :  -0.7621847297573647  --- MSE Fault S ----  0.032387366547791153
# Error in Simulation Fault T  for Each Blade :  -0.7621847297573647  --- Mean Squared Error Fault T :  9.359162082665692
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.4700345816027449
# Error in Simulation Health T  for Each Blade :  2.1734432536444848
# Error in Simulation Fault for Each Blade :  0.12781138067127795  --- MSE Fault S ----  0.09648240002815567
# Error in Simulation Fault T  for Each Blade :  0.12781138067127795  --- Mean Squared Error Fault T :  15.050659866784871
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0691961560820966
# Error in Simulation Health T  for Each Blade :  0.6703001056865818
# Error in Simulation Fault for Each Blade :  -0.7973490955533153  --- MSE Fault S ----  0.1343606848624139
# Error in Simulation Fault T  for Each Blade :  -0.7973490955533153  --- Mean Squared Error Fault T :  5.454260131350726
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.697483349860073
# Error in Simulation Health T  for Each Blade :  0.9069994166561668
# Error in Simulation Fault for Each Blade :  2.0513035662214816  --- MSE Fault S ----  0.11735408781862
# Error in Simulation Fault T  for Each Blade :  2.0513035662214816  --- Mean Squared Error Fault T :  6.045595450147999
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.8887549875290386
# Error in Simulation Health T  for Each Blade :  1.7050916977459467
# Error in Simulation Fault for Each Blade :  -1.1047528998920508  --- MSE Fault S ----  0.08970013468716193
# Error in Simulation Fault T  for Each Blade :  -1.1047528998920508  --- Mean Squared Error Fault T :  13.297414307545452
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.32486988743979994
# Error in Simulation Health T  for Each Blade :  1.6910909920807229
# Error in Simulation Fault for Each Blade :  1.5994704775633055  --- MSE Fault S ----  0.11200106098835068
# Error in Simulation Fault T  for Each Blade :  1.5994704775633055  --- Mean Squared Error Fault T :  12.940286729961471
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.3653857466545078
# Error in Simulation Health T  for Each Blade :  -1.2738823882756556
# Error in Simulation Fault for Each Blade :  0.015128700618896929  --- MSE Fault S ----  0.04778598144064431
# Error in Simulation Fault T  for Each Blade :  0.015128700618896929  --- Mean Squared Error Fault T :  10.440115611903543
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.13570306808629473
# Error in Simulation Health T  for Each Blade :  1.8240286459188981
# Error in Simulation Fault for Each Blade :  0.9699685130799933  --- MSE Fault S ----  0.04186290859488329
# Error in Simulation Fault T  for Each Blade :  0.9699685130799933  --- Mean Squared Error Fault T :  10.705572537244102
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.4727844658665876
# Error in Simulation Health T  for Each Blade :  0.1778490731243645
# Error in Simulation Fault for Each Blade :  -0.30183933093535753  --- MSE Fault S ----  0.04667613830975606
# Error in Simulation Fault T  for Each Blade :  -0.30183933093535753  --- Mean Squared Error Fault T :  6.8224221773519576
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.5740022248086807
# Error in Simulation Health T  for Each Blade :  -1.5828182088205278
# Error in Simulation Fault for Each Blade :  1.9967790290424765  --- MSE Fault S ----  0.0873597499981938
# Error in Simulation Fault T  for Each Blade :  1.9967790290424765  --- Mean Squared Error Fault T :  6.423051523369037
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.5893943238194308
# Error in Simulation Health T  for Each Blade :  -1.2130026036963615
# Error in Simulation Fault for Each Blade :  -0.3307381118106141  --- MSE Fault S ----  0.08829540423177212
# Error in Simulation Fault T  for Each Blade :  -0.3307381118106141  --- Mean Squared Error Fault T :  8.962333402854057
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.16482456177704097
# Error in Simulation Health T  for Each Blade :  1.415652703872226
# Error in Simulation Fault for Each Blade :  1.1381734844500548  --- MSE Fault S ----  0.08221696506133566
# Error in Simulation Fault T  for Each Blade :  1.1381734844500548  --- Mean Squared Error Fault T :  11.506229943992125
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.1791347216649797
# Error in Simulation Health T  for Each Blade :  0.37964354509214004
# Error in Simulation Fault for Each Blade :  1.0855865549067651  --- MSE Fault S ----  0.08602434005403774
# Error in Simulation Fault T  for Each Blade :  1.0855865549067651  --- Mean Squared Error Fault T :  15.362833064024167
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.2006787620962585
# Error in Simulation Health T  for Each Blade :  -0.038500063434720566
# Error in Simulation Fault for Each Blade :  -1.9069753488244436  --- MSE Fault S ----  0.1288181693076386
# Error in Simulation Fault T  for Each Blade :  -1.9069753488244436  --- Mean Squared Error Fault T :  7.396309081081628
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.3984273215297254
# Error in Simulation Health T  for Each Blade :  1.1055099151519059
# Error in Simulation Fault for Each Blade :  -1.590797979810316  --- MSE Fault S ----  0.14644196848279942
# Error in Simulation Fault T  for Each Blade :  -1.590797979810316  --- Mean Squared Error Fault T :  16.002303768127376
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.41464800430496807
# Error in Simulation Health T  for Each Blade :  0.30961744421700876
# Error in Simulation Fault for Each Blade :  -0.34432992783869487  --- MSE Fault S ----  0.057660160379842305
# Error in Simulation Fault T  for Each Blade :  -0.34432992783869487  --- Mean Squared Error Fault T :  12.849192625293078
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.95661670243077
# Error in Simulation Health T  for Each Blade :  2.4087399743207354
# Error in Simulation Fault for Each Blade :  -0.027796480156673464  --- MSE Fault S ----  0.00926186436142931
# Error in Simulation Fault T  for Each Blade :  -0.027796480156673464  --- Mean Squared Error Fault T :  7.81030119700911
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.4190992132557378
# Error in Simulation Health T  for Each Blade :  0.815276377429277
# Error in Simulation Fault for Each Blade :  0.4194844738309875  --- MSE Fault S ----  0.0686180911453992
# Error in Simulation Fault T  for Each Blade :  0.4194844738309875  --- Mean Squared Error Fault T :  6.06805803488928
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.6267236234523219
# Error in Simulation Health T  for Each Blade :  2.2998520716874955
# Error in Simulation Fault for Each Blade :  -0.7452880768045436  --- MSE Fault S ----  0.1284836372820791
# Error in Simulation Fault T  for Each Blade :  -0.7452880768045436  --- Mean Squared Error Fault T :  9.60497239294516
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.6673071315887533
# Error in Simulation Health T  for Each Blade :  -0.32024522897683116
# Error in Simulation Fault for Each Blade :  1.6171017508378358  --- MSE Fault S ----  0.10201303131638456
# Error in Simulation Fault T  for Each Blade :  1.6171017508378358  --- Mean Squared Error Fault T :  5.95204652845808
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.2984151903221024
# Error in Simulation Health T  for Each Blade :  -0.3024872363825697
# Error in Simulation Fault for Each Blade :  -1.533863558145839  --- MSE Fault S ----  0.1334948851320432
# Error in Simulation Fault T  for Each Blade :  -1.533863558145839  --- Mean Squared Error Fault T :  5.919787882051069
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.6985906802237398
# Error in Simulation Health T  for Each Blade :  0.6019966307005493
# Error in Simulation Fault for Each Blade :  0.20965402458170912  --- MSE Fault S ----  0.08978909684659499
# Error in Simulation Fault T  for Each Blade :  0.20965402458170912  --- Mean Squared Error Fault T :  4.769372460045198
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.3206728121178217
# Error in Simulation Health T  for Each Blade :  -0.3135451838028427
# Error in Simulation Fault for Each Blade :  -0.5250085585597541  --- MSE Fault S ----  0.08190716292276694
# Error in Simulation Fault T  for Each Blade :  -0.5250085585597541  --- Mean Squared Error Fault T :  7.46176782324586
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.09883502888935558
# Error in Simulation Health T  for Each Blade :  2.3275754427759328
# Error in Simulation Fault for Each Blade :  -0.3334872449597126  --- MSE Fault S ----  0.05103493586739124
# Error in Simulation Fault T  for Each Blade :  -0.3334872449597126  --- Mean Squared Error Fault T :  7.569743592521802
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.43204240778775427
# Error in Simulation Health T  for Each Blade :  1.2506103012301426
# Error in Simulation Fault for Each Blade :  -1.0465210216097316  --- MSE Fault S ----  0.10651762725720625
# Error in Simulation Fault T  for Each Blade :  -1.0465210216097316  --- Mean Squared Error Fault T :  13.961075691166984
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  3.344021852395045
# Error in Simulation Health T  for Each Blade :  2.3844650326906764
# Error in Simulation Fault for Each Blade :  -1.1949621015768004  --- MSE Fault S ----  0.09404487310022903
# Error in Simulation Fault T  for Each Blade :  -1.1949621015768004  --- Mean Squared Error Fault T :  7.840872334967585
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.872468712083273
# Error in Simulation Health T  for Each Blade :  -2.8167483448225124
# Error in Simulation Fault for Each Blade :  -2.0750003634748735  --- MSE Fault S ----  0.1297729324434828
# Error in Simulation Fault T  for Each Blade :  -2.0750003634748735  --- Mean Squared Error Fault T :  14.6690999582855
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.6969791479061058
# Error in Simulation Health T  for Each Blade :  0.9143351126497112
# Error in Simulation Fault for Each Blade :  -0.33407318004622466  --- MSE Fault S ----  0.02256176289034891
# Error in Simulation Fault T  for Each Blade :  -0.33407318004622466  --- Mean Squared Error Fault T :  8.717737910994943
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.1691544068256885
# Error in Simulation Health T  for Each Blade :  1.3709766042300435
# Error in Simulation Fault for Each Blade :  -0.8065996321789712  --- MSE Fault S ----  0.02810891631435634
# Error in Simulation Fault T  for Each Blade :  -0.8065996321789712  --- Mean Squared Error Fault T :  8.941189531681491
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.37802205004157186
# Error in Simulation Health T  for Each Blade :  -2.510575992162819
# Error in Simulation Fault for Each Blade :  -1.0969193985911856  --- MSE Fault S ----  0.21806029558490259
# Error in Simulation Fault T  for Each Blade :  -1.0969193985911856  --- Mean Squared Error Fault T :  11.553654097893071
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.012573423396244
# Error in Simulation Health T  for Each Blade :  0.6756481786358353
# Error in Simulation Fault for Each Blade :  1.3387293661027124  --- MSE Fault S ----  0.13663487450375375
# Error in Simulation Fault T  for Each Blade :  1.3387293661027124  --- Mean Squared Error Fault T :  15.195317812327739
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.356855780790203
# Error in Simulation Health T  for Each Blade :  1.505399817047862
# Error in Simulation Fault for Each Blade :  -0.05296834439570608  --- MSE Fault S ----  0.07642517344929649
# Error in Simulation Fault T  for Each Blade :  -0.05296834439570608  --- Mean Squared Error Fault T :  10.0401314149554
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.0514774818978356
# Error in Simulation Health T  for Each Blade :  2.1931472378986037
# Error in Simulation Fault for Each Blade :  0.634977947232592  --- MSE Fault S ----  0.09379525748489888
# Error in Simulation Fault T  for Each Blade :  0.634977947232592  --- Mean Squared Error Fault T :  11.868674987406399
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.830047228714532
# Error in Simulation Health T  for Each Blade :  0.7864820550500036
# Error in Simulation Fault for Each Blade :  -0.7237274677422656  --- MSE Fault S ----  0.06619845013465564
# Error in Simulation Fault T  for Each Blade :  -0.7237274677422656  --- Mean Squared Error Fault T :  9.762178005173437
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.1847582532213563
# Error in Simulation Health T  for Each Blade :  0.7719214715993243
# Error in Simulation Fault for Each Blade :  -0.7250319225368824  --- MSE Fault S ----  0.028287110708113603
# Error in Simulation Fault T  for Each Blade :  -0.7250319225368824  --- Mean Squared Error Fault T :  3.7639086370660215
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.588534079780981
# Error in Simulation Health T  for Each Blade :  1.631434789918944
# Error in Simulation Fault for Each Blade :  2.177870042777923  --- MSE Fault S ----  0.1491390892441543
# Error in Simulation Fault T  for Each Blade :  2.177870042777923  --- Mean Squared Error Fault T :  14.45683104519505
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.22728144248046078
# Error in Simulation Health T  for Each Blade :  0.31024601061288504
# Error in Simulation Fault for Each Blade :  0.174708128755233  --- MSE Fault S ----  0.12750966482774292
# Error in Simulation Fault T  for Each Blade :  0.174708128755233  --- Mean Squared Error Fault T :  9.559344760298623
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.061974334144018
# Error in Simulation Health T  for Each Blade :  1.6941645976364712
# Error in Simulation Fault for Each Blade :  -0.6906871935057062  --- MSE Fault S ----  0.023792630394245232
# Error in Simulation Fault T  for Each Blade :  -0.6906871935057062  --- Mean Squared Error Fault T :  8.751739188310227
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.7588092779323365
# Error in Simulation Health T  for Each Blade :  0.5647585831068413
# Error in Simulation Fault for Each Blade :  -2.8209623950069194  --- MSE Fault S ----  0.19835506982142626
# Error in Simulation Fault T  for Each Blade :  -2.8209623950069194  --- Mean Squared Error Fault T :  10.185050094249931
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.20225111053483857
# Error in Simulation Health T  for Each Blade :  -0.1955710007532896
# Error in Simulation Fault for Each Blade :  1.4929787440564928  --- MSE Fault S ----  0.123592378352342
# Error in Simulation Fault T  for Each Blade :  1.4929787440564928  --- Mean Squared Error Fault T :  8.686951377751866
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.8103913987755869
# Error in Simulation Health T  for Each Blade :  0.01683022656408384
# Error in Simulation Fault for Each Blade :  -1.418602592771584  --- MSE Fault S ----  0.235999650783589
# Error in Simulation Fault T  for Each Blade :  -1.418602592771584  --- Mean Squared Error Fault T :  15.12961959873349
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.9406490336439064
# Error in Simulation Health T  for Each Blade :  3.3095554620388876
# Error in Simulation Fault for Each Blade :  0.47673280084428016  --- MSE Fault S ----  0.07352526834207533
# Error in Simulation Fault T  for Each Blade :  0.47673280084428016  --- Mean Squared Error Fault T :  12.505420864438163
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.9300178663000871
# Error in Simulation Health T  for Each Blade :  1.8267235540570543
# Error in Simulation Fault for Each Blade :  -1.479751828315301  --- MSE Fault S ----  0.24071601261483874
# Error in Simulation Fault T  for Each Blade :  -1.479751828315301  --- Mean Squared Error Fault T :  10.81182820713339
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.14690258420783486
# Error in Simulation Health T  for Each Blade :  -0.8319993150677099
# Error in Simulation Fault for Each Blade :  -0.6418150188399394  --- MSE Fault S ----  0.015166229282163629
# Error in Simulation Fault T  for Each Blade :  -0.6418150188399394  --- Mean Squared Error Fault T :  8.549532139374463
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.39249490407740284
# Error in Simulation Health T  for Each Blade :  1.2928972004294232
# Error in Simulation Fault for Each Blade :  0.3635445169235756  --- MSE Fault S ----  0.048446444532870066
# Error in Simulation Fault T  for Each Blade :  0.3635445169235756  --- Mean Squared Error Fault T :  4.814493648708308
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.96890933520926
# Error in Simulation Health T  for Each Blade :  1.1511986513648367
# Error in Simulation Fault for Each Blade :  1.5952127705307806  --- MSE Fault S ----  0.09919611855173653
# Error in Simulation Fault T  for Each Blade :  1.5952127705307806  --- Mean Squared Error Fault T :  9.972129471981033
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.2654308074447833
# Error in Simulation Health T  for Each Blade :  0.7480931398288879
# Error in Simulation Fault for Each Blade :  -0.5971228739996137  --- MSE Fault S ----  0.06335506576934559
# Error in Simulation Fault T  for Each Blade :  -0.5971228739996137  --- Mean Squared Error Fault T :  14.30128086070144
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.02212998832016
# Error in Simulation Health T  for Each Blade :  1.2404583218309888
# Error in Simulation Fault for Each Blade :  1.983691329335759  --- MSE Fault S ----  0.1237344319562526
# Error in Simulation Fault T  for Each Blade :  1.983691329335759  --- Mean Squared Error Fault T :  6.903562416449951
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0870246790473388
# Error in Simulation Health T  for Each Blade :  2.2137984888154696
# Error in Simulation Fault for Each Blade :  -2.829369709898824  --- MSE Fault S ----  0.3226972804171346
# Error in Simulation Fault T  for Each Blade :  -2.829369709898824  --- Mean Squared Error Fault T :  12.40778304006905
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.9165411200298599
# Error in Simulation Health T  for Each Blade :  1.3612810069219972
# Error in Simulation Fault for Each Blade :  -1.9603406875247045  --- MSE Fault S ----  0.24880668934649078
# Error in Simulation Fault T  for Each Blade :  -1.9603406875247045  --- Mean Squared Error Fault T :  11.509089052525567
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0814449581195151
# Error in Simulation Health T  for Each Blade :  -0.6745630396982258
# Error in Simulation Fault for Each Blade :  -4.655870633334789  --- MSE Fault S ----  0.5881792669452487
# Error in Simulation Fault T  for Each Blade :  -4.655870633334789  --- Mean Squared Error Fault T :  14.944858957361362
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.5353342476169947
# Error in Simulation Health T  for Each Blade :  -0.566414247008241
# Error in Simulation Fault for Each Blade :  0.30643735221186286  --- MSE Fault S ----  0.08257260382275008
# Error in Simulation Fault T  for Each Blade :  0.30643735221186286  --- Mean Squared Error Fault T :  11.50856163626804
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.028175725769978843
# Error in Simulation Health T  for Each Blade :  0.9642619785948794
# Error in Simulation Fault for Each Blade :  0.6846208681010868  --- MSE Fault S ----  0.0519704045909716
# Error in Simulation Fault T  for Each Blade :  0.6846208681010868  --- Mean Squared Error Fault T :  6.208573431831504
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.263907496516131
# Error in Simulation Health T  for Each Blade :  2.605325869157216
# Error in Simulation Fault for Each Blade :  -0.0024410504706420255  --- MSE Fault S ----  0.04497213993184184
# Error in Simulation Fault T  for Each Blade :  -0.0024410504706420255  --- Mean Squared Error Fault T :  9.58875852609413
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.7749046767616419
# Error in Simulation Health T  for Each Blade :  2.4455797274535387
# Error in Simulation Fault for Each Blade :  -0.8060653567171157  --- MSE Fault S ----  0.04889197453687938
# Error in Simulation Fault T  for Each Blade :  -0.8060653567171157  --- Mean Squared Error Fault T :  3.991979773305788
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.1879298769074018
# Error in Simulation Health T  for Each Blade :  0.0526706902534968
# Error in Simulation Fault for Each Blade :  -0.34418603047353713  --- MSE Fault S ----  0.0735857037740894
# Error in Simulation Fault T  for Each Blade :  -0.34418603047353713  --- Mean Squared Error Fault T :  8.950477721158522
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0197380650214296
# Error in Simulation Health T  for Each Blade :  0.7987844678498557
# Error in Simulation Fault for Each Blade :  -0.3303685949346573  --- MSE Fault S ----  0.07851187504817496
# Error in Simulation Fault T  for Each Blade :  -0.3303685949346573  --- Mean Squared Error Fault T :  12.115211782464995
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.5540682402334713
# Error in Simulation Health T  for Each Blade :  0.5330091233769647
# Error in Simulation Fault for Each Blade :  0.027159025495805844  --- MSE Fault S ----  0.02300569393576958
# Error in Simulation Fault T  for Each Blade :  0.027159025495805844  --- Mean Squared Error Fault T :  6.4791354847210565
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.41235662076721846
# Error in Simulation Health T  for Each Blade :  1.3488597196398096
# Error in Simulation Fault for Each Blade :  0.14396354401177858  --- MSE Fault S ----  0.16151539961049174
# Error in Simulation Fault T  for Each Blade :  0.14396354401177858  --- Mean Squared Error Fault T :  14.82342711746592
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.07162550469539442
# Error in Simulation Health T  for Each Blade :  1.4790225199016014
# Error in Simulation Fault for Each Blade :  -0.36848108789604206  --- MSE Fault S ----  0.10619403517708936
# Error in Simulation Fault T  for Each Blade :  -0.36848108789604206  --- Mean Squared Error Fault T :  8.332936606443399
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0832128896118236
# Error in Simulation Health T  for Each Blade :  2.266683121100276
# Error in Simulation Fault for Each Blade :  -0.6440997983357861  --- MSE Fault S ----  0.07450616495836539
# Error in Simulation Fault T  for Each Blade :  -0.6440997983357861  --- Mean Squared Error Fault T :  10.494899190810195
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0502982119458972
# Error in Simulation Health T  for Each Blade :  -0.007457574778591436
# Error in Simulation Fault for Each Blade :  -0.5997989982557779  --- MSE Fault S ----  0.12865730904268133
# Error in Simulation Fault T  for Each Blade :  -0.5997989982557779  --- Mean Squared Error Fault T :  10.4558039957666
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.4220208526587144
# Error in Simulation Health T  for Each Blade :  1.6866472330387738
# Error in Simulation Fault for Each Blade :  -0.9901226097546008  --- MSE Fault S ----  0.04869816584608928
# Error in Simulation Fault T  for Each Blade :  -0.9901226097546008  --- Mean Squared Error Fault T :  12.401815962296554
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.8062868670981054
# Error in Simulation Health T  for Each Blade :  1.4462158384274537
# Error in Simulation Fault for Each Blade :  0.8110427257819404  --- MSE Fault S ----  0.07824919415950826
# Error in Simulation Fault T  for Each Blade :  0.8110427257819404  --- Mean Squared Error Fault T :  9.671302839073983
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.1521748763086117
# Error in Simulation Health T  for Each Blade :  0.1903104569955052
# Error in Simulation Fault for Each Blade :  -1.7037154323253643  --- MSE Fault S ----  0.0928925669198666
# Error in Simulation Fault T  for Each Blade :  -1.7037154323253643  --- Mean Squared Error Fault T :  11.363873660650363
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.995677357547448
# Error in Simulation Health T  for Each Blade :  0.8718819275351264
# Error in Simulation Fault for Each Blade :  0.6982718042521792  --- MSE Fault S ----  0.061808930526405986
# Error in Simulation Fault T  for Each Blade :  0.6982718042521792  --- Mean Squared Error Fault T :  10.449953572947477
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.4631371059894058
# Error in Simulation Health T  for Each Blade :  3.063293208268413
# Error in Simulation Fault for Each Blade :  -0.539755086391319  --- MSE Fault S ----  0.096227835304246
# Error in Simulation Fault T  for Each Blade :  -0.539755086391319  --- Mean Squared Error Fault T :  9.380156863749859
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.43166716085178747
# Error in Simulation Health T  for Each Blade :  2.1304084162643537
# Error in Simulation Fault for Each Blade :  -2.0712927562479146  --- MSE Fault S ----  0.09141015648342694
# Error in Simulation Fault T  for Each Blade :  -2.0712927562479146  --- Mean Squared Error Fault T :  13.177422320170578
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.10723074898790674
# Error in Simulation Health T  for Each Blade :  0.8578483911525656
# Error in Simulation Fault for Each Blade :  -0.3774313777302236  --- MSE Fault S ----  0.0600493917281796
# Error in Simulation Fault T  for Each Blade :  -0.3774313777302236  --- Mean Squared Error Fault T :  12.634219862025082
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.520596172192218
# Error in Simulation Health T  for Each Blade :  0.42088714235865954
# Error in Simulation Fault for Each Blade :  -0.6284881049255171  --- MSE Fault S ----  0.05626875896724987
# Error in Simulation Fault T  for Each Blade :  -0.6284881049255171  --- Mean Squared Error Fault T :  4.988187154791279
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.18236729360404
# Error in Simulation Health T  for Each Blade :  1.6555602384584276
# Error in Simulation Fault for Each Blade :  -2.5919463748676215  --- MSE Fault S ----  0.19563466812537467
# Error in Simulation Fault T  for Each Blade :  -2.5919463748676215  --- Mean Squared Error Fault T :  10.300306122787926
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  2.970916110817754
# Error in Simulation Health T  for Each Blade :  0.2461688767585133
# Error in Simulation Fault for Each Blade :  1.5856304850806149  --- MSE Fault S ----  0.1395109610727131
# Error in Simulation Fault T  for Each Blade :  1.5856304850806149  --- Mean Squared Error Fault T :  12.965019324974461
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0054306542389608
# Error in Simulation Health T  for Each Blade :  -0.05786187265889908
# Error in Simulation Fault for Each Blade :  0.28663791538245853  --- MSE Fault S ----  0.021120923071890216
# Error in Simulation Fault T  for Each Blade :  0.28663791538245853  --- Mean Squared Error Fault T :  6.476364750905294
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.5050367994253178
# Error in Simulation Health T  for Each Blade :  0.43767545145127396
# Error in Simulation Fault for Each Blade :  -0.9079639655194764  --- MSE Fault S ----  0.027613821475400768
# Error in Simulation Fault T  for Each Blade :  -0.9079639655194764  --- Mean Squared Error Fault T :  5.743140465861534
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.2127244072592247
# Error in Simulation Health T  for Each Blade :  0.7051351925632607
# Error in Simulation Fault for Each Blade :  -4.010491846803799  --- MSE Fault S ----  0.44792505587004205
# Error in Simulation Fault T  for Each Blade :  -4.010491846803799  --- Mean Squared Error Fault T :  8.313865761999528
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.4652852032976902
# Error in Simulation Health T  for Each Blade :  1.485847007355777
# Error in Simulation Fault for Each Blade :  0.012745986217814087  --- MSE Fault S ----  0.011244899581772862
# Error in Simulation Fault T  for Each Blade :  0.012745986217814087  --- Mean Squared Error Fault T :  8.301223466799003
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.13176274052393855
# Error in Simulation Health T  for Each Blade :  0.35533640363177676
# Error in Simulation Fault for Each Blade :  -1.280600938033289  --- MSE Fault S ----  0.04441786991338716
# Error in Simulation Fault T  for Each Blade :  -1.280600938033289  --- Mean Squared Error Fault T :  12.488338856185196
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.1863698854054665
# Error in Simulation Health T  for Each Blade :  -0.1963752011794111
# Error in Simulation Fault for Each Blade :  0.3979870746504597  --- MSE Fault S ----  0.07017065299770725
# Error in Simulation Fault T  for Each Blade :  0.3979870746504597  --- Mean Squared Error Fault T :  9.905858570496054
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.508305117408832
# Error in Simulation Health T  for Each Blade :  -1.4945850805910088
# Error in Simulation Fault for Each Blade :  -0.5383336113927817  --- MSE Fault S ----  0.013424357316155345
# Error in Simulation Fault T  for Each Blade :  -0.5383336113927817  --- Mean Squared Error Fault T :  3.2052706228032335
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.6260100476756238
# Error in Simulation Health T  for Each Blade :  -0.005268777127896751
# Error in Simulation Fault for Each Blade :  2.017978489729602  --- MSE Fault S ----  0.1664955830727137
# Error in Simulation Fault T  for Each Blade :  2.017978489729602  --- Mean Squared Error Fault T :  9.077851085447284
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.6359195661070673
# Error in Simulation Health T  for Each Blade :  0.2686585209741499
# Error in Simulation Fault for Each Blade :  -1.3019406033529641  --- MSE Fault S ----  0.06483033440592954
# Error in Simulation Fault T  for Each Blade :  -1.3019406033529641  --- Mean Squared Error Fault T :  9.346863069244206
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.3439333962765643
# Error in Simulation Health T  for Each Blade :  0.8434803630663819
# Error in Simulation Fault for Each Blade :  0.9337081249629597  --- MSE Fault S ----  0.04251196946652181
# Error in Simulation Fault T  for Each Blade :  0.9337081249629597  --- Mean Squared Error Fault T :  6.575788179948181
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.27140835970794397
# Error in Simulation Health T  for Each Blade :  0.2936623141259185
# Error in Simulation Fault for Each Blade :  -0.8649502660283339  --- MSE Fault S ----  0.04155507760256386
# Error in Simulation Fault T  for Each Blade :  -0.8649502660283339  --- Mean Squared Error Fault T :  7.245001958430767
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.9597395363779531
# Error in Simulation Health T  for Each Blade :  1.3606780391220008
# Error in Simulation Fault for Each Blade :  -0.27759034836100493  --- MSE Fault S ----  0.07550937198915532
# Error in Simulation Fault T  for Each Blade :  -0.27759034836100493  --- Mean Squared Error Fault T :  8.901163546039841
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.3110491099261155
# Error in Simulation Health T  for Each Blade :  -0.44092940224807364
# Error in Simulation Fault for Each Blade :  0.2579591813045845  --- MSE Fault S ----  0.04101445235354896
# Error in Simulation Fault T  for Each Blade :  0.2579591813045845  --- Mean Squared Error Fault T :  2.312497515721565
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.1424857339322667
# Error in Simulation Health T  for Each Blade :  2.63608981299315
# Error in Simulation Fault for Each Blade :  -0.49154739583685503  --- MSE Fault S ----  0.020092588100575907
# Error in Simulation Fault T  for Each Blade :  -0.49154739583685503  --- Mean Squared Error Fault T :  9.205897179756525
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.5278471369948547
# Error in Simulation Health T  for Each Blade :  -0.5912100448132751
# Error in Simulation Fault for Each Blade :  1.778437835865764  --- MSE Fault S ----  0.1176904352830675
# Error in Simulation Fault T  for Each Blade :  1.778437835865764  --- Mean Squared Error Fault T :  7.635492973370217
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.192685108792021
# Error in Simulation Health T  for Each Blade :  3.2749902017674275
# Error in Simulation Fault for Each Blade :  -0.03992205218537315  --- MSE Fault S ----  0.10068173224138204
# Error in Simulation Fault T  for Each Blade :  -0.03992205218537315  --- Mean Squared Error Fault T :  8.796904276363344
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.4507221704749895
# Error in Simulation Health T  for Each Blade :  2.168751040091328
# Error in Simulation Fault for Each Blade :  1.0019696831291447  --- MSE Fault S ----  0.071622697188525
# Error in Simulation Fault T  for Each Blade :  1.0019696831291447  --- Mean Squared Error Fault T :  10.462771784476917
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.951696285527992
# Error in Simulation Health T  for Each Blade :  0.9426879200999378
# Error in Simulation Fault for Each Blade :  -0.4756177594063671  --- MSE Fault S ----  0.08738704576822644
# Error in Simulation Fault T  for Each Blade :  -0.4756177594063671  --- Mean Squared Error Fault T :  10.718974980624722
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.22624157587023386
# Error in Simulation Health T  for Each Blade :  1.184865113029057
# Error in Simulation Fault for Each Blade :  1.5873002004420718  --- MSE Fault S ----  0.048067164341450176
# Error in Simulation Fault T  for Each Blade :  1.5873002004420718  --- Mean Squared Error Fault T :  5.7696058798858205
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.6168990888055701
# Error in Simulation Health T  for Each Blade :  -0.016457051116153476
# Error in Simulation Fault for Each Blade :  2.6484001845747205  --- MSE Fault S ----  0.1659810514844845
# Error in Simulation Fault T  for Each Blade :  2.6484001845747205  --- Mean Squared Error Fault T :  12.294965483746822
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.419005857064075
# Error in Simulation Health T  for Each Blade :  0.15739323845084607
# Error in Simulation Fault for Each Blade :  -1.0367439442323585  --- MSE Fault S ----  0.13669739447913945
# Error in Simulation Fault T  for Each Blade :  -1.0367439442323585  --- Mean Squared Error Fault T :  11.95876463323856
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.4592863044913544
# Error in Simulation Health T  for Each Blade :  -0.3232612873490739
# Error in Simulation Fault for Each Blade :  -1.4289758400042998  --- MSE Fault S ----  0.07591048363596438
# Error in Simulation Fault T  for Each Blade :  -1.4289758400042998  --- Mean Squared Error Fault T :  3.5938620805488632
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.5266781750522505
# Error in Simulation Health T  for Each Blade :  0.6933119372079792
# Error in Simulation Fault for Each Blade :  0.5063025079423338  --- MSE Fault S ----  0.017141717166924395
# Error in Simulation Fault T  for Each Blade :  0.5063025079423338  --- Mean Squared Error Fault T :  2.5891130750784472
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.7983969251499734
# Error in Simulation Health T  for Each Blade :  -0.3908231304288152
# Error in Simulation Fault for Each Blade :  -1.461713534095894  --- MSE Fault S ----  0.07084347251874427
# Error in Simulation Fault T  for Each Blade :  -1.461713534095894  --- Mean Squared Error Fault T :  10.046529069242816
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.31126066344433556
# Error in Simulation Health T  for Each Blade :  1.026865658066633
# Error in Simulation Fault for Each Blade :  -0.4227313958433616  --- MSE Fault S ----  0.014637110685754587
# Error in Simulation Fault T  for Each Blade :  -0.4227313958433616  --- Mean Squared Error Fault T :  2.6126504293981285
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.9182683078135163
# Error in Simulation Health T  for Each Blade :  -0.03097081688193204
# Error in Simulation Fault for Each Blade :  1.0090140342593408  --- MSE Fault S ----  0.07044909450423377
# Error in Simulation Fault T  for Each Blade :  1.0090140342593408  --- Mean Squared Error Fault T :  6.024781595807034
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.4216947934030917
# Error in Simulation Health T  for Each Blade :  2.720455020859624
# Error in Simulation Fault for Each Blade :  -0.5173911852806925  --- MSE Fault S ----  0.015968075394718277
# Error in Simulation Fault T  for Each Blade :  -0.5173911852806925  --- Mean Squared Error Fault T :  7.796310813314791
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.44374787933476023
# Error in Simulation Health T  for Each Blade :  1.1076743280115942
# Error in Simulation Fault for Each Blade :  -1.6014996195420954  --- MSE Fault S ----  0.0636113121647353
# Error in Simulation Fault T  for Each Blade :  -1.6014996195420954  --- Mean Squared Error Fault T :  5.938799409985022
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.31089226414677196
# Error in Simulation Health T  for Each Blade :  -0.11035947922300071
# Error in Simulation Fault for Each Blade :  -0.7969968383338069  --- MSE Fault S ----  0.044115717884531135
# Error in Simulation Fault T  for Each Blade :  -0.7969968383338069  --- Mean Squared Error Fault T :  7.072351759372471
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.12130674819931642
# Error in Simulation Health T  for Each Blade :  -2.95444608031456
# Error in Simulation Fault for Each Blade :  -0.6804100597854974  --- MSE Fault S ----  0.1357362037718219
# Error in Simulation Fault T  for Each Blade :  -0.6804100597854974  --- Mean Squared Error Fault T :  10.954408298624971
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.630806559272774
# Error in Simulation Health T  for Each Blade :  -0.4789317858176778
# Error in Simulation Fault for Each Blade :  1.2244908958594793  --- MSE Fault S ----  0.17767034417230346
# Error in Simulation Fault T  for Each Blade :  1.2244908958594793  --- Mean Squared Error Fault T :  12.913749425664548
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.46105960131738666
# Error in Simulation Health T  for Each Blade :  0.7141344017947182
# Error in Simulation Fault for Each Blade :  0.6180661723168643  --- MSE Fault S ----  0.08897469374263099
# Error in Simulation Fault T  for Each Blade :  0.6180661723168643  --- Mean Squared Error Fault T :  4.077985958945907
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.393832428420279
# Error in Simulation Health T  for Each Blade :  2.3341131409523967
# Error in Simulation Fault for Each Blade :  -1.5290978950314476  --- MSE Fault S ----  0.08779602527826556
# Error in Simulation Fault T  for Each Blade :  -1.5290978950314476  --- Mean Squared Error Fault T :  13.009630494402515
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  4.175328038338017
# Error in Simulation Health T  for Each Blade :  -0.43619786978522157
# Error in Simulation Fault for Each Blade :  -1.7049164428171075  --- MSE Fault S ----  0.13626426024055946
# Error in Simulation Fault T  for Each Blade :  -1.7049164428171075  --- Mean Squared Error Fault T :  10.921803970610602
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.9819439023876093
# Error in Simulation Health T  for Each Blade :  -0.8136747874260406
# Error in Simulation Fault for Each Blade :  -1.3766067610347823  --- MSE Fault S ----  0.07877347149388948
# Error in Simulation Fault T  for Each Blade :  -1.3766067610347823  --- Mean Squared Error Fault T :  4.769286280802566
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.353776493794135
# Error in Simulation Health T  for Each Blade :  0.42411291183968824
# Error in Simulation Fault for Each Blade :  0.3740038936591217  --- MSE Fault S ----  0.04185252411264803
# Error in Simulation Fault T  for Each Blade :  0.3740038936591217  --- Mean Squared Error Fault T :  4.159876099137904
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.2400896439555393
# Error in Simulation Health T  for Each Blade :  -0.030699579807093702
# Error in Simulation Fault for Each Blade :  -0.10506067737159785  --- MSE Fault S ----  0.0692282268310876
# Error in Simulation Fault T  for Each Blade :  -0.10506067737159785  --- Mean Squared Error Fault T :  6.302952478895537
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.5781855683846953
# Error in Simulation Health T  for Each Blade :  1.209565867281241
# Error in Simulation Fault for Each Blade :  1.6552276137684503  --- MSE Fault S ----  0.15425362935199677
# Error in Simulation Fault T  for Each Blade :  1.6552276137684503  --- Mean Squared Error Fault T :  5.531783688053081
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.219663710464843
# Error in Simulation Health T  for Each Blade :  0.4235672789184801
# Error in Simulation Fault for Each Blade :  -0.35474232187231136  --- MSE Fault S ----  0.1319038711743508
# Error in Simulation Fault T  for Each Blade :  -0.35474232187231136  --- Mean Squared Error Fault T :  5.536945311641497
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.34843537360512444
# Error in Simulation Health T  for Each Blade :  -0.14323640091914602
# Error in Simulation Fault for Each Blade :  -0.22460504584710161  --- MSE Fault S ----  0.11781129415493306
# ...
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.5493656171626438
# Error in Simulation Health T  for Each Blade :  1.6534329866070863
# Error in Simulation Fault for Each Blade :  -1.4429287161939437  --- MSE Fault S ----  0.06456846600430961
# Error in Simulation Fault T  for Each Blade :  -1.4429287161939437  --- Mean Squared Error Fault T :  10.176651745066446
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.37362098924372256
# Error in Simulation Health T  for Each Blade :  1.304582962808651
# Error in Simulation Fault for Each Blade :  -0.44603103932216204  --- MSE Fault S ----  0.20231040304859882
# Error in Simulation Fault T  for Each Blade :  -0.44603103932216204  --- Mean Squared Error Fault T :  6.861345100131399
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.21714503791574136
# Error in Simulation Health T  for Each Blade :  1.6450714312085593
# Error in Simulation Fault for Each Blade :  0.31437532348037034  --- MSE Fault S ----  0.07370977184162075
# Error in Simulation Fault T  for Each Blade :  0.31437532348037034  --- Mean Squared Error Fault T :  6.28364976774866
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -3.771994928698539
# Error in Simulation Health T  for Each Blade :  1.1435196811572235
# Error in Simulation Fault for Each Blade :  2.175819654468816  --- MSE Fault S ----  0.11449284962796097
# Error in Simulation Fault T  for Each Blade :  2.175819654468816  --- Mean Squared Error Fault T :  4.874846312942128
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.15563167153215285
# Error in Simulation Health T  for Each Blade :  1.9083109524415764
# Error in Simulation Fault for Each Blade :  -1.4431408835407362  --- MSE Fault S ----  0.061535583272222576
# Error in Simulation Fault T  for Each Blade :  -1.4431408835407362  --- Mean Squared Error Fault T :  6.672431337139007
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.4686043313827155
# Error in Simulation Health T  for Each Blade :  2.0293117155487153
# Error in Simulation Fault for Each Blade :  -0.2136206255067894  --- MSE Fault S ----  0.051166121370958745
# Error in Simulation Fault T  for Each Blade :  -0.2136206255067894  --- Mean Squared Error Fault T :  5.7828290130770705
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.1076989881894792
# Error in Simulation Health T  for Each Blade :  1.3036106210642844
# Error in Simulation Fault for Each Blade :  0.3295995414916897  --- MSE Fault S ----  0.14186229370443817
# Error in Simulation Fault T  for Each Blade :  0.3295995414916897  --- Mean Squared Error Fault T :  7.760453249049199
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.158003322115913
# Error in Simulation Health T  for Each Blade :  1.7372018776389817
# Error in Simulation Fault for Each Blade :  -1.954618232382017  --- MSE Fault S ----  0.15252648383177586
# Error in Simulation Fault T  for Each Blade :  -1.954618232382017  --- Mean Squared Error Fault T :  6.433044446454026
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.4760663349891945
# Error in Simulation Health T  for Each Blade :  2.6567843434794542
# Error in Simulation Fault for Each Blade :  -0.7135445903266615  --- MSE Fault S ----  0.12295358391450611
# Error in Simulation Fault T  for Each Blade :  -0.7135445903266615  --- Mean Squared Error Fault T :  4.787951633238121
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.3667232874751911
# Error in Simulation Health T  for Each Blade :  2.333788692033838
# Error in Simulation Fault for Each Blade :  -0.7783298873091749  --- MSE Fault S ----  0.05450991861612173
# Error in Simulation Fault T  for Each Blade :  -0.7783298873091749  --- Mean Squared Error Fault T :  4.301284150202929
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.2309846584273625
# Error in Simulation Health T  for Each Blade :  2.747406400744956
# Error in Simulation Fault for Each Blade :  -2.0490780343161603  --- MSE Fault S ----  0.1788867203279083
# Error in Simulation Fault T  for Each Blade :  -2.0490780343161603  --- Mean Squared Error Fault T :  9.376116097446863
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.3308550013331464
# Error in Simulation Health T  for Each Blade :  2.6330331226507524
# Error in Simulation Fault for Each Blade :  0.7944149380237795  --- MSE Fault S ----  0.09710745571677402
# Error in Simulation Fault T  for Each Blade :  0.7944149380237795  --- Mean Squared Error Fault T :  7.577460308474503
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.3579545421341659
# Error in Simulation Health T  for Each Blade :  1.895257706789479
# Error in Simulation Fault for Each Blade :  1.4121649072715203  --- MSE Fault S ----  0.08399229071621482
# Error in Simulation Fault T  for Each Blade :  1.4121649072715203  --- Mean Squared Error Fault T :  6.057051392467997
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.33658853179745796
# Error in Simulation Health T  for Each Blade :  2.190270066822848
# Error in Simulation Fault for Each Blade :  0.16392163228187395  --- MSE Fault S ----  0.07736086000160557
# Error in Simulation Fault T  for Each Blade :  0.16392163228187395  --- Mean Squared Error Fault T :  6.1353172046776026
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.34625529649003783
# Error in Simulation Health T  for Each Blade :  0.09166842073429571
# Error in Simulation Fault for Each Blade :  -0.44761407613405857  --- MSE Fault S ----  0.07937438559539403
# Error in Simulation Fault T  for Each Blade :  -0.44761407613405857  --- Mean Squared Error Fault T :  5.891836868665584
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.119966261609566
# Error in Simulation Health T  for Each Blade :  0.9461747126620972
# Error in Simulation Fault for Each Blade :  -0.3241532251601549  --- MSE Fault S ----  0.0282199774491762
# Error in Simulation Fault T  for Each Blade :  -0.3241532251601549  --- Mean Squared Error Fault T :  6.515691341678486
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.8498222468367038
# Error in Simulation Health T  for Each Blade :  0.7961177999258546
# Error in Simulation Fault for Each Blade :  -0.4701707507838395  --- MSE Fault S ----  0.03229324168764309
# Error in Simulation Fault T  for Each Blade :  -0.4701707507838395  --- Mean Squared Error Fault T :  2.097185807707873
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.14244059672179077
# Error in Simulation Health T  for Each Blade :  0.5444283807589301
# Error in Simulation Fault for Each Blade :  -0.07649853630276704  --- MSE Fault S ----  0.004505976794110489
# Error in Simulation Fault T  for Each Blade :  -0.07649853630276704  --- Mean Squared Error Fault T :  3.584275391020368
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.4241384313123382
# Error in Simulation Health T  for Each Blade :  3.0914649988032976
# Error in Simulation Fault for Each Blade :  -1.5998381150596606  --- MSE Fault S ----  0.055705325679427965
# Error in Simulation Fault T  for Each Blade :  -1.5998381150596606  --- Mean Squared Error Fault T :  4.81544583206049
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.26249262797766626
# Error in Simulation Health T  for Each Blade :  0.5503690586361616
# Error in Simulation Fault for Each Blade :  -0.23938863162119706  --- MSE Fault S ----  0.016060857243628355
# Error in Simulation Fault T  for Each Blade :  -0.23938863162119706  --- Mean Squared Error Fault T :  6.390086901889084
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.6417570375679711
# Error in Simulation Health T  for Each Blade :  1.4146331521634026
# Error in Simulation Fault for Each Blade :  0.003589119327706891  --- MSE Fault S ----  0.06988735403104994
# Error in Simulation Fault T  for Each Blade :  0.003589119327706891  --- Mean Squared Error Fault T :  7.6777379546614135
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.3541591363411236
# Error in Simulation Health T  for Each Blade :  1.7325536812961935
# Error in Simulation Fault for Each Blade :  -0.28474699581010143  --- MSE Fault S ----  0.08794100329756427
# Error in Simulation Fault T  for Each Blade :  -0.28474699581010143  --- Mean Squared Error Fault T :  7.3933486336583725
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.8482308408404249
# Error in Simulation Health T  for Each Blade :  -0.4205189415909163
# Error in Simulation Fault for Each Blade :  -0.3462531240319271  --- MSE Fault S ----  0.009595636565286452
# Error in Simulation Fault T  for Each Blade :  -0.3462531240319271  --- Mean Squared Error Fault T :  9.393705568442483
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.9194481731630593
# Error in Simulation Health T  for Each Blade :  0.8681510474695098
# Error in Simulation Fault for Each Blade :  -1.1165466107786788  --- MSE Fault S ----  0.12367715749148052
# Error in Simulation Fault T  for Each Blade :  -1.1165466107786788  --- Mean Squared Error Fault T :  9.96551417798009
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.6307702192825593
# Error in Simulation Health T  for Each Blade :  -0.5709615967725572
# Error in Simulation Fault for Each Blade :  -1.4623535455893766  --- MSE Fault S ----  0.1322370107552327
# Error in Simulation Fault T  for Each Blade :  -1.4623535455893766  --- Mean Squared Error Fault T :  9.655733446739545
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.26718753440065424
# Error in Simulation Health T  for Each Blade :  3.407690504949397
# Error in Simulation Fault for Each Blade :  -0.13397825060162916  --- MSE Fault S ----  0.05713531741139544
# Error in Simulation Fault T  for Each Blade :  -0.13397825060162916  --- Mean Squared Error Fault T :  10.138108265488293
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.2268795443989855
# Error in Simulation Health T  for Each Blade :  2.4054750752838907
# Error in Simulation Fault for Each Blade :  -1.4355831278531257  --- MSE Fault S ----  0.13906919472205528
# Error in Simulation Fault T  for Each Blade :  -1.4355831278531257  --- Mean Squared Error Fault T :  10.086041605171422
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -1.0697618222564615
# Error in Simulation Health T  for Each Blade :  0.9477894963201665
# Error in Simulation Fault for Each Blade :  0.5487825407298739  --- MSE Fault S ----  0.009677450988855226
# Error in Simulation Fault T  for Each Blade :  0.5487825407298739  --- Mean Squared Error Fault T :  5.571165466281106
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.2387621621227334
# Error in Simulation Health T  for Each Blade :  1.6804869838337524
# Error in Simulation Fault for Each Blade :  -0.7834561042279955  --- MSE Fault S ----  0.14024961172796455
# Error in Simulation Fault T  for Each Blade :  -0.7834561042279955  --- Mean Squared Error Fault T :  4.217334940893686
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  1.1576297123369335
# Error in Simulation Health T  for Each Blade :  -0.6283871944801762
# Error in Simulation Fault for Each Blade :  1.3852060782093623  --- MSE Fault S ----  0.08251133027711506
# Error in Simulation Fault T  for Each Blade :  1.3852060782093623  --- Mean Squared Error Fault T :  7.274241063704392
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.8290438698300666
# Error in Simulation Health T  for Each Blade :  0.20656304302563244
# Error in Simulation Fault for Each Blade :  -0.38763084488870003  --- MSE Fault S ----  0.020049397716631435
# Error in Simulation Fault T  for Each Blade :  -0.38763084488870003  --- Mean Squared Error Fault T :  2.601415290617164
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -0.5627449971758407
# Error in Simulation Health T  for Each Blade :  -0.46057142611849944
# Error in Simulation Fault for Each Blade :  1.3257195673273539  --- MSE Fault S ----  0.07368324297198917
# Error in Simulation Fault T  for Each Blade :  1.3257195673273539  --- Mean Squared Error Fault T :  6.925447402481955
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  0.4809895167723608
# Error in Simulation Health T  for Each Blade :  1.1540486765362585
# Error in Simulation Fault for Each Blade :  0.5592475117829507  --- MSE Fault S ----  0.0937152656499261
# Error in Simulation Fault T  for Each Blade :  0.5592475117829507  --- Mean Squared Error Fault T :  9.193827038677261
#  ----- for each Blade Simulated -----
# Error in Simulation Health for Each Blade :  -2.3545104488164115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-383c82f896b0> in <cell line: 1>()
#     256           model_health_t = LinearRegression()
#     257           model_health_t.fit(x_train, z_train)
# --> 258           z_predict_health_t = model_health_t.predict(x_test)
#     259           intercept_0 = model_health_t.intercept_
#     260           coef1 = model_health_t.coef_[0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     283         check_is_fitted(self)
#     284
# --> 285         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286         coef_ = self.coef_
#     287         if coef_.ndim == 1:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     874                 return isinstance(dtype, SparseDtype)
#     875
# --> 876             if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
#     877                 warnings.warn(
#     878                     "pandas.DataFrame with sparse columns found."
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in dtypes(self)
#    6363         dtype: object
#    6364         """
# -> 6365         data = self._mgr.get_dtypes()
#    6366         return self._constructor_sliced(data, index=self._info_axis, dtype=np.object_)
#    6367
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in get_dtypes(self)
#     278     def get_dtypes(self) -> npt.NDArray[np.object_]:
#     279         dtypes = np.array([blk.dtype for blk in self.blocks], dtype=object)
# --> 280         return dtypes.take(self.blknos)
#     281
#     282     @property
#
# KeyboardInterrupt:
