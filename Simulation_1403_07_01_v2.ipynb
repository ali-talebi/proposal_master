# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D
import os
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense , Dropout
from tensorflow.keras.utils import to_categorical

# %%
root_path = '/content/drive/MyDrive/Malek_Master/code/Total_Data_Simulation'

# %%
total_file_link = []
for i in os.listdir(root_path) :
  total_file_link.append(root_path+f'/{i}')

# %%
total_alpha_content = [ i / 1000 for i in range( 1 , 999 ) ]
total_flat_content  = [ i for i in range(1 , 10  ) ]
total_location      = list(range( 5 , 16))

# %%
points = []
start_x = 65
start_y = [0 , -5 , -10.0 ]
for i in range(15) :
  start_x +=  15

  for j in range(3) :
    points.append([start_x , start_y[j] , 0 ] )

points.append([330 , -2.5 , 0 ])
points.append([330 , -7.5 , 0 ])
points.append([330 , -12.5 , 0 ])
total_points = np.array(points)
plt.scatter(total_points[ : ,  0 ] , total_points[ : , 1 ] , label = "target" )
plt.legend()
plt.title("Blade Shape - Picture 1.7 page 7 document volume 2 ")
plt.xlabel(" X (in) ")
plt.ylabel(" Y (in) ")
plt.grid()
plt.show()

# %%
total_simulation = {
    'bias_correlation' : [] ,
    'betha_0_correlation' : [] ,
    'betha_1_correlation' : [] ,
    'betha_2_correlation' : [] ,
    'betha_3_correlation' : [] ,
    'betha_4_correlation' : [] ,
    'betha_5_correlation' : [] ,
    'alpha' : [] ,
    'flap'  : [] ,
    'accuracy_nav' : [] ,
    'accuracy_random_forest' : []

}

# %%
for iter_alpha in total_alpha_content :
  for iter_flat in total_flat_content :
    print(f"iter_alpha : {iter_alpha} | iter_flat : {iter_flat} ")
    params_health  = []
    params_fault   = []
    params_fault_t = []
    for iter_link in total_file_link :
      df_table_change     = pd.read_csv(iter_link)
      for locate in total_location:
        related_x = -1
        related_y = -1
        related_z = -1
        for iteration in range(1):
          alpha = 0
          term  = 0
          Flat_Add = 0
          noise_activate = ( (np.random.randn() + 1 ) / 100 )
          #print( f'Alpha : {iter_alpha} ' ,  f'Table Change : {iter_link}' , ' -- ' , f'Locate : {locate} ' , ' -- ' , f"Iter : {iteration}" , ' -- ' , '')
          select_location = 0

          total_health_iter  = []
          total_fault_iter   = []
          total_fault_t_iter = []
          new_data_simulated_ = []
          new_data_simulated_fault = []
          new_data_simulated_fault_t = []


          for i in range(df_table_change.shape[0]):
            x_mean = df_table_change.iloc[i, 1]
            x_std  = df_table_change.iloc[i, 2]
            y_mean = df_table_change.iloc[i, 3]
            y_std  = df_table_change.iloc[i, 4]
            z_mean = df_table_change.iloc[i, 5]
            z_std  = df_table_change.iloc[i, 6]

            if i > locate :
              alpha = iter_alpha
              term  = -1 * ( alpha * abs( i - locate ) + noise_activate )
              Flat_Add  = iter_flat / 10

            for element in total_points[i * 3: (i + 1) * 3, :]:
              x_sample = element[0]
              y_sample = element[1]
              z_sample = element[2]
              rng = np.random.default_rng()
              x_added  = rng.normal(x_mean, x_std, size=1)
              x_added  = x_added.tolist()[0]
              x_sample += related_x * x_added

              y_added  = rng.normal(y_mean, y_std, size=1)
              y_added  = y_added.tolist()[0]
              y_sample += related_y * y_added

              z_added  = rng.normal(z_mean, z_std, size=1)
              z_base   = z_sample

              z_added_term  = z_added.tolist()[0] + term
              z_added       = z_added.tolist()[0]
              z_sample_new_term = z_base + related_z * z_added_term
              z_sample_new      = z_base + related_z * z_added
              z_flat  = z_sample_new_term
              if select_location == 0 :
                if np.random.randint(0 ,2 ) :
                  z_flat = z_sample_new_term + Flat_Add










              new_data_simulated_.append([ x_sample, y_sample, z_sample_new  ])
              new_data_simulated_fault.append([ x_sample, y_sample, z_sample_new_term  ])
              new_data_simulated_fault_t.append([ x_sample, y_sample, z_flat  ])

              total_health_iter.append([ x_sample, y_sample, z_sample_new  ])
              total_fault_iter.append([ x_sample, y_sample, z_sample_new_term  ])
              total_fault_t_iter.append([ x_sample, y_sample, z_flat  ])

          #fig = plt.figure(figsize=(30 , 10 ))
          #ax0 = fig.add_subplot(1 , 6 , 1 , projection='3d' )
          #ax1 = fig.add_subplot(1 , 6 , 2 , projection='3d' )
          #ax2 = fig.add_subplot(1 , 6 , 3 , projection='3d' )
          #ax3 = fig.add_subplot(1 , 6 , 4 )
          #ax4 = fig.add_subplot(1 , 6 , 5 )
          #ax5 = fig.add_subplot(1 , 6 , 6 )

          #total_health_iter = np.array(total_health_iter)
          #total_health_iter = np.array(total_health_iter)
          #total_fault_iter = np.array(total_fault_iter)
          #total_fault_t_iter = np.array(total_fault_t_iter)
          print(f"iter_alpha : {iter_alpha} , flap: {iter_flat} , locate : {locate} ,  iteration : {iteration} ")
          #ax0.scatter3D(total_health_iter[: , 0 ] , total_health_iter[: , 1 ] , total_health_iter[: , 2 ]  , label='H'  )
          #ax0.scatter3D(total_fault_iter[: , 0 ] , total_fault_iter[: , 1 ] , total_fault_iter[: , 2 ]  , label='F1' , c ='b'  )
          #ax1.scatter3D(total_fault_iter[: , 0 ] , total_fault_iter[: , 1 ] , total_fault_iter[: , 2 ]  ,       label='F1' , c ='b'    )
          #ax1.scatter3D(total_fault_t_iter[: , 0 ] , total_fault_t_iter[: , 1 ] , total_fault_t_iter[: , 2 ]  , label='F2' , c='r'  )
          #ax2.scatter3D(total_fault_t_iter[: , 0 ] , total_fault_t_iter[: , 1 ] , total_fault_t_iter[: , 2 ]  , label='F2' , c='r'    )

          #ax3.scatter(total_health_iter[: , 0 ]  , total_health_iter[: , 2 ]  ,       label='H' , c ='b' )
          #ax3.scatter(total_fault_iter[: , 0 ]  , total_fault_iter[: , 2 ]  ,       label='F1' , c ='r' )

          #ax4.scatter(total_health_iter[: , 0 ]  , total_health_iter[: , 2 ]  ,       label='H' , c ='b' )
          #ax4.scatter(total_fault_t_iter[: , 0 ]  , total_fault_t_iter[: , 2 ]  , label='F2' , c='r')

          #ax5.scatter(total_fault_iter[: , 0 ]  , total_fault_iter[: , 2 ]  ,       label='F1' , c ='b' )
          #ax5.scatter(total_fault_t_iter[: , 0 ]  , total_fault_t_iter[: , 2 ]  , label='F2' , c='r')

          #ax0.legend()
          #ax0.grid()
          #ax1.legend()
          #ax1.grid()
          #ax2.legend()
          #ax2.grid()
          #ax3.legend()
          #ax3.grid()

          #ax4.legend()
          #ax4.grid()
          #ax5.legend()
          #ax5.grid()

          #plt.show()




          new_data_simulated_        = np.array(new_data_simulated_)
          new_data_simulated_fault   = np.array(new_data_simulated_fault)
          new_data_simulated_fault_t = np.array(new_data_simulated_fault_t)


          #fig = plt.figure(figsize=(30, 10))
          df_health = pd.DataFrame()
          df_health['X_'] = new_data_simulated_[:, 0]
          df_health['Y_'] = new_data_simulated_[:, 1]
          df_health['Z_'] = new_data_simulated_[:, 2]

          poly = PolynomialFeatures(degree=2)
          x_poly = poly.fit_transform(df_health[['X_', 'Y_']])
          scaler = StandardScaler()
          df_stander = pd.DataFrame(scaler.fit_transform(x_poly), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander['Z_'] = df_health['Z_']
          x_train, x_test, z_train, z_test = train_test_split(df_stander[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']],
                                                                          df_stander["Z_"])
          model = LinearRegression()
          model.fit(x_train, z_train)
          z_predict = model.predict(x_test)
          intercept_0 = model.intercept_
          coef1 = model.coef_[0]
          coef2 = model.coef_[1]
          coef3 = model.coef_[2]
          coef4 = model.coef_[3]
          coef5 = model.coef_[4]
          coef6 = model.coef_[5]

          total_new_generate = []
          total_error = []
          for i in range(len(df_health['X_'])):
            new_value = intercept_0 + coef1 * df_stander.iloc[i, 0] + coef2 * df_stander.iloc[i, 1] + coef3 * df_stander.iloc[i, 2] + coef4 * df_stander.iloc[i, 3] + coef5 * df_stander.iloc[i, 4]
            + coef6 * df_stander.iloc[i, 5]
            total_new_generate.append(new_value)
            error = df_stander.iloc[i, -1] - new_value
            total_error.append(error)


          #class health == 0
          params_health.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict, z_test),locate , 0 , iter_alpha ,  iter_flat  ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]
          # ---- setup for class Fault ----
          df_fault = pd.DataFrame()
          df_fault['X_'] = new_data_simulated_fault[:, 0]
          df_fault['Y_'] = new_data_simulated_fault[:, 1]
          df_fault['Z_'] = new_data_simulated_fault[:, 2]




          poly_fault = PolynomialFeatures(degree=2)
          x_poly_fault = poly_fault.fit_transform(df_fault[['X_', 'Y_']])
          scaler_fault = StandardScaler()
          df_stander_fault = pd.DataFrame(scaler_fault.fit_transform(x_poly_fault), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander_fault['Z_'] = df_fault['Z_']
          x_train_fault , x_test_fault , z_train_fault , z_test_fault = train_test_split(df_stander_fault[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']], df_stander_fault["Z_"])
          model_fault = LinearRegression()
          model_fault.fit(x_train_fault, z_train_fault)
          z_predict_fault = model_fault.predict(x_test_fault)
          intercept_0 = model_fault.intercept_
          coef1 = model_fault.coef_[0]
          coef2 = model_fault.coef_[1]
          coef3 = model_fault.coef_[2]
          coef4 = model_fault.coef_[3]
          coef5 = model_fault.coef_[4]
          coef6 = model_fault.coef_[5]
          total_new_generate_fault = []
          total_error_fault = []
          for i in range(len(df_fault['X_'])):
            new_value = intercept_0 + coef1 * df_stander_fault.iloc[i, 0] + coef2 * df_stander_fault.iloc[i, 1] + coef3 *  df_stander_fault.iloc[i, 2] + coef4 * df_stander_fault.iloc[i, 3] + coef5 * df_stander_fault.iloc[i, 4]  + coef6 * df_stander_fault.iloc[i, 5]
            total_new_generate_fault.append(new_value)
            error_Fault = df_stander_fault.iloc[i, -1] - new_value
            total_error_fault.append(error_Fault)

          params_fault.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict_fault, z_test_fault),locate ,  1 , iter_alpha ,  iter_flat ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]

          # ---- setup for class Fault T ----

          df_fault_t = pd.DataFrame()
          df_fault_t['X_'] = new_data_simulated_fault_t[:, 0]
          df_fault_t['Y_'] = new_data_simulated_fault_t[:, 1]
          df_fault_t['Z_'] = new_data_simulated_fault_t[:, 2]




          poly_fault_t = PolynomialFeatures(degree=2)
          x_poly_fault_t = poly_fault_t.fit_transform(df_fault_t[['X_', 'Y_']])
          scaler_fault_t = StandardScaler()
          df_stander_fault_t = pd.DataFrame(scaler_fault_t.fit_transform(x_poly_fault_t), columns=['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2', ])
          df_stander_fault_t['Z_'] = df_fault_t['Z_']
          x_train_fault_t , x_test_fault_t , z_train_fault_t , z_test_fault_t = train_test_split(df_stander_fault_t[['0', 'X', 'Y', 'x1^2', 'x1x2', 'x2^2']], df_stander_fault["Z_"])
          model_fault_t = LinearRegression()
          model_fault_t.fit(x_train_fault_t, z_train_fault_t)
          z_predict_fault = model_fault_t.predict(x_test_fault_t)
          intercept_0 = model_fault_t.intercept_
          coef1 = model_fault_t.coef_[0]
          coef2 = model_fault_t.coef_[1]
          coef3 = model_fault_t.coef_[2]
          coef4 = model_fault_t.coef_[3]
          coef5 = model_fault_t.coef_[4]
          coef6 = model_fault_t.coef_[5]
          total_new_generate_fault_t = []
          total_error_fault_t = []
          for i in range(len(df_fault['X_'])):
            new_value = intercept_0 + coef1 * df_stander_fault_t.iloc[i, 0] + coef2 * df_stander_fault_t.iloc[i, 1] + coef3 *  df_stander_fault_t.iloc[i, 2] + coef4 * df_stander_fault_t.iloc[i, 3] + coef5 * df_stander_fault_t.iloc[i, 4]  + coef6 * df_stander_fault_t.iloc[i, 5]
            total_new_generate_fault_t.append(new_value)
            error_Fault = df_stander_fault_t.iloc[i, -1] - new_value
            total_error_fault.append(error_Fault)

          params_fault_t.append([intercept_0, coef1, coef2, coef3, coef4, coef5, coef6, mean_squared_error(z_predict_fault, z_test_fault),locate ,  2 , iter_alpha ,  iter_flat ])
          total_change = [1, 1]
          related_x *= total_change[np.random.randint(0, 2)]
          related_y *= total_change[np.random.randint(0, 2)]
          related_z *= total_change[np.random.randint(0, 2)]




#----
    params_health = np.array(params_health)
    df_params = pd.DataFrame({'bias':params_health[: , 0 ] , 'betha_0':params_health[ : , 1 ] , 'betha_1':params_health[ : , 2 ] , 'betha_2':params_health[ : , 3 ] ,  'betha_3':params_health[ : , 4 ] , 'betha_4':params_health[ : , 5 ] , 'betha_5':params_health[ : , 6 ] , 'error' : params_health[ : , 7 ]  ,
                          'locate' : params_health[: , 8 ].astype(int)   , 'class' :params_health[: , 9 ] ,
                              'alpha' :params_health[: , 10 ] , 'flap' : params_health[: , 11 ] } )



    params_fault = np.array(params_fault)
    df_params_fault = pd.DataFrame({'bias':params_fault[: , 0 ] , 'betha_0':params_fault[ : , 1 ] , 'betha_1':params_fault[ : , 2 ] , 'betha_2':params_fault[ : , 3 ] ,  'betha_3':params_fault[ : , 4 ] , 'betha_4':params_fault[ : , 5 ] , 'betha_5':params_fault[ : , 6 ] , 'error' : params_fault[ : , 7 ]  ,
                            'locate' : params_fault[: , 8 ].astype(int) ,
                                    'class' :params_fault[: , 9 ]  ,
                                    'alpha' :params_fault[: , 10 ] , 'flap' : params_fault[: , 11 ] }   )


    params_fault_t = np.array(params_fault_t)
    df_params_fault_t = pd.DataFrame({'bias':params_fault_t[: , 0 ] , 'betha_0':params_fault_t[ : , 1 ] , 'betha_1':params_fault_t[ : , 2 ] , 'betha_2':params_fault_t[ : , 3 ] ,  'betha_3':params_fault_t[ : , 4 ] , 'betha_4':params_fault_t[ : , 5 ] , 'betha_5':params_fault_t[ : , 6 ] , 'error' : params_fault_t[ : , 7 ]  ,
                            'locate' : params_fault_t[: , 8 ].astype(int) ,
                                    'class' :params_fault_t[: , 9 ]  ,
                                    'alpha' :params_fault_t[: , 10 ] , 'flap' : params_fault_t[: , 11 ] }  )







    concat_2_df_health_fault = pd.concat([df_params , df_params_fault , df_params_fault_t ] , axis = 0 )
    df_corr = concat_2_df_health_fault.corr()







  # --- learning
    #plt.figure(figsize= (10 , 10 ) )
    #ax = sns.heatmap(df_corr , annot=True )
    #print(df_corr)
    #plt.show()
    total_simulation['alpha'].append(iter_alpha)
    total_simulation['flap'].append(iter_flat)
    total_simulation['bias_correlation'].append(df_corr['class']['bias'])
    total_simulation['betha_0_correlation'].append(df_corr['class']['betha_0'])
    total_simulation['betha_1_correlation'].append(df_corr['class']['betha_1'])
    total_simulation['betha_2_correlation'].append(df_corr['class']['betha_2'])
    total_simulation['betha_3_correlation'].append(df_corr['class']['betha_3'])
    total_simulation['betha_4_correlation'].append(df_corr['class']['betha_4'])
    total_simulation['betha_5_correlation'].append(df_corr['class']['betha_5'])



    #df2_health  =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 0 ]
    #df2_fault   =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 1 ]
    #df2_fault_t =  concat_2_df_health_fault[concat_2_df_health_fault['class'] == 2 ]


    stander_u = StandardScaler()
    stand_df_with_out = concat_2_df_health_fault.drop(['class' , 'alpha' , 'flap'] , axis = 1 )
    stand_df_with_out = pd.DataFrame(stander_u.fit_transform(stand_df_with_out )  , columns = stand_df_with_out.columns )
    x_u_train , x_u_test , y_u_train , y_u_test = train_test_split(stand_df_with_out , concat_2_df_health_fault['class'] , random_state=42 , test_size=0.2  )
    obj_gaunb = GaussianNB()
    obj_gaunb.fit(x_u_train , y_u_train )
    pre_nb = obj_gaunb.predict(x_u_test)
    accuray_nav = accuracy_score(pre_nb ,y_u_test )
    print(f"accuracy Nave Bays : {accuray_nav}")
    total_simulation['accuracy_nav'].append(accuray_nav)
    classifier_1 = RandomForestClassifier()
    classifier_1.fit(x_u_train , y_u_train )
    pre_random = classifier_1.predict(x_u_test)
    accuracy_random_forest = accuracy_score(pre_random ,y_u_test )
    print(f"accuracy accuracy_random_forest  : {accuracy_random_forest}")
    total_simulation['accuracy_random_forest'].append(accuracy_random_forest)


    print(" ----------------- //////// End This Iter alpha and Flap //////// ------------------------- ")





  if iter_alpha > 0.003 :
    break
# Out:
# iter_alpha : 0.001 | iter_flat : 1
# iter_alpha : 0.001 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 1 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 2
# iter_alpha : 0.001 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 2 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.65
# accuracy accuracy_random_forest  : 0.45
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 3
# iter_alpha : 0.001 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 3 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.75
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 4
# iter_alpha : 0.001 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 4 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.8
# accuracy accuracy_random_forest  : 0.85
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 5
# iter_alpha : 0.001 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 5 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.65
# accuracy accuracy_random_forest  : 0.6
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 6
# iter_alpha : 0.001 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 6 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.45
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 7
# iter_alpha : 0.001 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 7 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.7
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 8
# iter_alpha : 0.001 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 8 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.7
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.001 | iter_flat : 9
# iter_alpha : 0.001 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.001 , flap: 9 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.65
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 1
# iter_alpha : 0.002 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 1 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.45
# accuracy accuracy_random_forest  : 0.5
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 2
# iter_alpha : 0.002 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 2 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.7
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 3
# iter_alpha : 0.002 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 3 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.6
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 4
# iter_alpha : 0.002 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 4 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.5
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 5
# iter_alpha : 0.002 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 5 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.7
# accuracy accuracy_random_forest  : 0.8
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 6
# iter_alpha : 0.002 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 6 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.7
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 7
# iter_alpha : 0.002 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 7 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.6
# accuracy accuracy_random_forest  : 0.55
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 8
# iter_alpha : 0.002 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 8 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.6
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.002 | iter_flat : 9
# iter_alpha : 0.002 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.002 , flap: 9 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.6
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.003 | iter_flat : 1
# iter_alpha : 0.003 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 1 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.7
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.003 | iter_flat : 2
# iter_alpha : 0.003 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 2 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.003 | iter_flat : 3
# iter_alpha : 0.003 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 3 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.55
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.003 | iter_flat : 4
# iter_alpha : 0.003 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.003 , flap: 4 , locate : 13 ,  iteration : 0
# ...
# iter_alpha : 0.004 , flap: 2 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 2 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.55
# accuracy accuracy_random_forest  : 0.7
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 3
# iter_alpha : 0.004 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 3 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.9
# accuracy accuracy_random_forest  : 0.85
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 4
# iter_alpha : 0.004 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 4 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.7
# accuracy accuracy_random_forest  : 0.6
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 5
# iter_alpha : 0.004 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 5 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.6
# accuracy accuracy_random_forest  : 0.75
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 6
# iter_alpha : 0.004 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 6 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.7
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 7
# iter_alpha : 0.004 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 7 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.7
# accuracy accuracy_random_forest  : 0.6
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 8
# iter_alpha : 0.004 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 8 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.45
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------
# iter_alpha : 0.004 | iter_flat : 9
# iter_alpha : 0.004 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 15 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 5 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 6 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 7 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 8 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 9 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 10 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 11 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 12 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 13 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 14 ,  iteration : 0
# iter_alpha : 0.004 , flap: 9 , locate : 15 ,  iteration : 0
# accuracy Nave Bays : 0.75
# accuracy accuracy_random_forest  : 0.65
#  ----------------- //////// End This Iter alpha and Flap //////// -------------------------

# %%
pd.DataFrame(total_simulation)
# Out:
#     bias_correlation  betha_0_correlation  betha_1_correlation  \
# 0           0.028671                  NaN            -0.264934
# 1           0.009118                  NaN             0.073107
# 2           0.006197                  NaN            -0.198469
# 3           0.005657                  NaN            -0.111376
# 4           0.007273                  NaN            -0.135722
# 5          -0.002113                  NaN            -0.076183
# 6           0.008967                  NaN            -0.050606
# 7           0.007113                  NaN            -0.133248
# 8           0.016919                  NaN            -0.097533
# 9           0.006358                  NaN            -0.039523
# 10          0.013707                  NaN            -0.071272
# 11          0.013044                  NaN            -0.014316
# 12          0.009892                  NaN             0.035062
# 13          0.007885                  NaN             0.008600
# 14          0.016255                  NaN            -0.079540
# 15          0.008070                  NaN            -0.055001
# 16          0.002687                  NaN             0.094376
# 17          0.007227                  NaN            -0.139289
# 18          0.006104                  NaN             0.089406
# 19          0.026151                  NaN            -0.069450
# 20          0.011151                  NaN             0.009960
# 21          0.011721                  NaN            -0.010802
# 22          0.006361                  NaN             0.063473
# 23          0.030404                  NaN            -0.141500
# 24          0.009157                  NaN            -0.013007
# 25          0.016789                  NaN            -0.012746
# 26          0.000096                  NaN             0.051347
# 27          0.002458                  NaN            -0.105272
# 28          0.015854                  NaN            -0.047380
# 29          0.010756                  NaN             0.033422
# 30          0.016566                  NaN             0.029203
# 31         -0.001093                  NaN             0.109466
# 32          0.012524                  NaN            -0.133961
# 33          0.008769                  NaN             0.066653
# 34          0.007970                  NaN            -0.028601
# 35          0.002207                  NaN            -0.015817
#
#     betha_2_correlation  betha_3_correlation  betha_4_correlation  \
# 0             -0.142173             0.274581             0.139115
# 1             -0.072983            -0.034025             0.084490
# 2             -0.115107             0.188742             0.046408
# 3             -0.007102             0.103926             0.006417
# 4             -0.020975             0.163306             0.086901
# 5             -0.014026             0.074825             0.043875
# 6              0.010065             0.053263            -0.073388
# 7              0.010320             0.136965             0.034750
# 8              0.035130             0.121847             0.052602
# 9              0.092860             0.052539            -0.035599
# 10            -0.013018             0.061428            -0.076418
# 11             0.073167             0.024255            -0.032370
# 12            -0.006351            -0.027013            -0.000998
# 13            -0.064667             0.021216             0.094793
# 14            -0.001627             0.088003            -0.000809
# 15             0.245780             0.034327            -0.121555
# 16            -0.053798            -0.055957             0.132455
# 17             0.108544             0.113156            -0.113726
# 18            -0.022194            -0.071394            -0.012831
# 19             0.112646             0.091765            -0.075476
# 20            -0.153292             0.021685             0.100116
# 21             0.071799            -0.006242            -0.105252
# 22             0.073104            -0.068113            -0.062317
# 23            -0.084657             0.177364             0.020232
# 24            -0.149579             0.052736             0.118146
# 25            -0.122434             0.041681             0.110866
# 26            -0.031558            -0.051727            -0.036191
# 27            -0.203480             0.135751             0.219461
# 28            -0.012190             0.073386             0.030230
# 29             0.239536            -0.088328            -0.332643
# 30            -0.095695            -0.007474             0.023905
# 31            -0.077610            -0.096818             0.012595
# 32             0.087005             0.138467            -0.036493
# 33            -0.100196            -0.028181             0.170739
# 34             0.147038             0.019530            -0.074461
# 35             0.047161             0.019837             0.004004
#
#     betha_5_correlation  alpha  flap  accuracy_nav  accuracy_random_forest
# 0             -0.101049  0.001     1          0.55                    0.65
# 1             -0.033649  0.001     2          0.65                    0.45
# 2             -0.123319  0.001     3          0.75                    0.75
# 3             -0.016279  0.001     4          0.80                    0.85
# 4              0.037696  0.001     5          0.65                    0.60
# 5              0.031003  0.001     6          0.55                    0.45
# 6             -0.044062  0.001     7          0.70                    0.65
# 7              0.043743  0.001     8          0.75                    0.70
# 8              0.081507  0.001     9          0.65                    0.65
# 9              0.092909  0.002     1          0.45                    0.50
# 10            -0.072541  0.002     2          0.70                    0.65
# 11             0.079076  0.002     3          0.60                    0.65
# 12             0.004446  0.002     4          0.55                    0.50
# 13            -0.047549  0.002     5          0.70                    0.80
# 14             0.005989  0.002     6          0.75                    0.70
# 15             0.264244  0.002     7          0.60                    0.55
# 16             0.036016  0.002     8          0.75                    0.60
# 17             0.089111  0.002     9          0.60                    0.65
# 18            -0.034865  0.003     1          0.75                    0.70
# 19             0.096902  0.003     2          0.55                    0.65
# 20            -0.158569  0.003     3          0.55                    0.55
# 21             0.017867  0.003     4          0.65                    0.65
# 22             0.082031  0.003     5          0.65                    0.55
# 23            -0.094002  0.003     6          0.80                    0.90
# 24            -0.109227  0.003     7          0.60                    0.60
# 25            -0.077484  0.003     8          0.70                    0.55
# 26            -0.071224  0.003     9          0.50                    0.35
# 27            -0.115574  0.004     1          0.65                    0.45
# 28             0.036461  0.004     2          0.55                    0.70
# 29             0.077434  0.004     3          0.90                    0.85
# 30            -0.118627  0.004     4          0.70                    0.60
# 31            -0.076023  0.004     5          0.60                    0.75
# 32             0.113373  0.004     6          0.75                    0.70
# 33            -0.007301  0.004     7          0.70                    0.60
# 34             0.138201  0.004     8          0.75                    0.45
# 35             0.076281  0.004     9          0.75                    0.65

# %%
df_fault
# Out:
#             X_         Y_        Z_
# 0    79.959374   0.014502  0.018280
# 1    79.955547  -4.985575  0.013881
# 2    79.958562  -9.990302  0.013052
# 3    95.018183   0.024275  0.008483
# 4    95.017301  -4.979920  0.013564
# 5    95.014168  -9.974853  0.007537
# 6   110.044927   0.050402  0.081703
# 7   110.042004  -4.951390  0.105535
# 8   110.042008  -9.953053  0.091274
# 9   125.052570   0.101824  0.112759
# 10  125.055792  -4.918215  0.166955
# 11  125.054615  -9.906844  0.160051
# 12  140.066098   0.163483  0.209657
# 13  140.063212  -4.889500  0.168811
# 14  140.064167  -9.860402  0.166845
# 15  155.098470   0.178121  0.343813
# 16  155.105688  -4.817501  0.341983
# 17  155.100744  -9.837851  0.360865
# 18  170.123384   0.192783  0.511313
# 19  170.126207  -4.814487  0.496416
# 20  170.126950  -9.818579  0.437416
# 21  185.150238   0.241740  0.683363
# 22  185.156438  -4.794338  0.669597
# 23  185.154943  -9.814511  0.688916
# 24  200.193253   0.238864  0.976045
# 25  200.201084  -4.738643  0.920533
# 26  200.191253  -9.746651  0.925972
# 27  215.226048   0.274346  1.438951
# 28  215.224715  -4.716979  1.395596
# 29  215.227145  -9.716480  1.532062
# 30  230.273232   0.367539  1.682085
# 31  230.273560  -4.791118  1.761989
# 32  230.272789  -9.709496  1.886085
# 33  245.303524   0.340606  2.175545
# 34  245.301519  -4.727357  2.340238
# 35  245.296950  -9.652353  2.246589
# 36  260.333921   0.395655  2.743727
# 37  260.336706  -4.568270  2.773744
# 38  260.333734  -9.669347  2.821568
# 39  275.383517   0.376471  3.390912
# 40  275.384156  -4.497153  3.327798
# 41  275.379727  -9.637986  3.336947
# 42  290.423132   0.379981  4.024511
# 43  290.428818  -4.652039  4.025185
# 44  290.426914  -9.699224  4.197177
# 45  330.392250  -2.136766  4.976955
# 46  330.388799  -7.071109  4.988566
# 47  330.388982 -12.027947  4.913375

# %%
fig = plt.figure(figsize=( 10 , 15  ))
ax10 = fig.add_subplot( 1 , 3 , 1 , projection='3d' )
ax11 = fig.add_subplot( 1 , 3 , 2  )
ax12 = fig.add_subplot( 1 , 3 , 3  )
ax10.scatter3D(df_fault_t.iloc[ : , 0 ] , df_fault_t.iloc[: , 1 ] , df_fault_t.iloc[: , 2 ] , label = 'T' , c = 'r' , s = 100 , alpha=0.5  )
ax10.scatter3D(df_health.iloc[ : , 0 ] , df_health.iloc[: , 1 ] , df_health.iloc[: , 2 ] , label = 'H'  , c = 'b' , s = 25 )
ax10.scatter3D(df_fault.iloc[ : , 0 ] , df_fault.iloc[: , 1 ] , df_fault.iloc[: , 2 ] , label = 'S'  , c ='aqua' , s = 50 )

ax11.scatter(df_fault_t.iloc[ : , 0 ] ,  df_fault_t.iloc[: , 2 ] , s = 50 , c = 'r' , label='T'  )
ax11.scatter(df_health.iloc[ : , 0 ]  ,  df_health.iloc[: , 2 ]  , s = 25 , c = 'b' , label='H'  )
ax11.legend()
ax11.grid()

ax12.legend()
ax12.grid()
ax10.legend()
ax10.grid()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_table_change
# Out:
#        r/R  mean_delta_x  std_delta_x  mean_delta_y  std_delta_y  \
# 0   0.2001        0.0434       0.0026       -0.0126       0.0013
# 1   0.2499       -0.0157       0.0019       -0.0235       0.0031
# 2   0.2998       -0.0418       0.0016       -0.0514       0.0053
# 3   0.3498       -0.0550       0.0016       -0.0961       0.0091
# 4   0.3913       -0.0646       0.0024       -0.1332       0.0133
# 5   0.4496       -0.1020       0.0026       -0.1704       0.0173
# 6   0.4997       -0.1255       0.0030       -0.2004       0.0207
# 7   0.5387       -0.1535       0.0028       -0.2193       0.0230
# 8   0.5996       -0.1964       0.0031       -0.2466       0.0273
# 9   0.6498       -0.2235       0.0031       -0.2726       0.0316
# 10  0.6998       -0.2741       0.0030       -0.2945       0.0354
# 11  0.7500       -0.3002       0.0029       -0.3091       0.0391
# 12  0.8001       -0.3363       0.0029       -0.3486       0.0430
# 13  0.8497       -0.3810       0.0031       -0.3719       0.0474
# 14  0.9102       -0.4236       0.0032       -0.3486       0.0526
# 15  0.9734       -0.3914       0.0037       -0.3834       0.0581
#
#     mean_delta_z  std_delta_z
# 0        -0.0162       0.0040
# 1        -0.0061       0.0079
# 2        -0.0781       0.0130
# 3        -0.1268       0.0216
# 4        -0.1839       0.0303
# 5        -0.3251       0.0405
# 6        -0.4803       0.0503
# 7        -0.6758       0.0569
# 8        -0.9893       0.0678
# 9        -1.3829       0.0783
# 10       -1.7870       0.0876
# 11       -2.2590       0.0965
# 12       -2.7745       0.1069
# 13       -3.3516       0.1185
# 14       -4.1247       0.1339
# 15       -4.8769       0.1475
